# %% [markdown]
# <a href="https://colab.research.google.com/github/indhujaya2014-web/Project1_Artifacts-/blob/main/Project1_Harvard_Art_Museums.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #HARVARD ART MUSEUMS

# %% [markdown]
# ##Installing the requests

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)

# %% [markdown]
# ##Fetching the records using harvard art museums api key

# %%
API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"

url = "https://api.harvardartmuseums.org/classification"

import requests

params = {
    "apikey":API_KEY,
    "size":100
}

response = requests.get(url, params)
response

# %%
data = response.json()
data

# %%
data.keys()

# %%
data['info']

# %%
data['records']

# %%
API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"
url = "https://api.harvardartmuseums.org/classification"

import requests
import pprint

params = {
    "apikey":API_KEY,
    "size":100
}
data = requests.get(url, params)
pprint.pprint(data.json()["records"])

# %% [markdown]
# ##Classification
#
# Find the classification names where the object count is >=2500

# %%
API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"

url = "https://api.harvardartmuseums.org/classification"

import requests


params = {
    "apikey":API_KEY,
    "size":100
}
print("The classification names where the object count is >= 2500\n")
response = requests.get(url, params)
data = response.json()
#response
classifications = []
for record in data["records"]:
    if record["objectcount"] >= 2500:
     classifications.append(record["name"])
     print(f"classification name:-{record["name"]}, objectcount - {record["objectcount"]}")
# Out:
# The classification names where the object count is >= 2500
#
# classification name:-Accessories (non-art), objectcount - 2862
# classification name:-Photographs, objectcount - 85799
# classification name:-Drawings, objectcount - 33976
# classification name:-Prints, objectcount - 72240
# classification name:-Paintings, objectcount - 6864
# classification name:-Sculpture, objectcount - 6643
# classification name:-Coins, objectcount - 20270
# classification name:-Vessels, objectcount - 6223
# classification name:-Textile Arts, objectcount - 3446
# classification name:-Archival Material, objectcount - 15737
# classification name:-Fragments, objectcount - 5218
# classification name:-Manuscripts, objectcount - 5001
# classification name:-Seals, objectcount - 5899
# classification name:-Straus Materials, objectcount - 5128

# %%
len(classifications)
# Out:
# 14

# %% [markdown]
# ##Classification details
# (for object url)

# %% [markdown]
# ###scroll through 25 pages and collect 2500 records

# %%
import requests
import pprint

API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"
url = "https://api.harvardartmuseums.org/object"

num_pages_to_fetch = 25
all_records = []


print(f"-------Starting Pagination for {num_pages_to_fetch} Pages-----")
for page in range(1, num_pages_to_fetch + 1):

  params = {
        "apikey": API_KEY,
        "size": 100,
        "page": page,
        "classification": "Coins"
  }
  response = requests.get(url, params=params)
  response.raise_for_status()
  data = response.json()
  records = data.get("records", [])
  all_records.extend(records)

  #print(f"successfully fetched len{records} - Records: {len(all_records)}")
print(f"Total records collected: {len(all_records)}----")

records
# Out:
# -------Starting Pagination for 25 Pages-----
# Total records collected: 2500----
# [{'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-06-02',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 5,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 4,
#   'rank': 2867,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '12',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'didrachm',
#     'dateonobject': None}},
#   'id': 169987,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-15',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141710,
#     'idsid': 18734087,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02463',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02463_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734087',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 7,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02463_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Didrachm of Rhodes',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.8186666666666667,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.14333333333333334,
#     'css3': '#696969'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.03685714285714286,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.001142857142857143,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '394 BCE-304 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -304,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169987',
#   'dateoffirstpageview': '2014-11-24',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2400',
#   'labeltext': None,
#   'datebegin': -394,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169987,
#   'techniqueid': 7320,
#   'dimensions': '6.42 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169987',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-02-08',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 7,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 4,
#   'rank': 2865,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '12',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'didrachm',
#     'dateonobject': None}},
#   'id': 169988,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-15',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141709,
#     'idsid': 18734085,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02461',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02461_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734085',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 13,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02461_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Didrachm of Rhodes',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9344761904761905,
#     'css3': '#000000'},
#    {'color': '#4b3232',
#     'spectrum': '#4ab851',
#     'hue': 'Red',
#     'percent': 0.0640952380952381,
#     'css3': '#2f4f4f'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.001238095238095238,
#     'css3': '#000000'},
#    {'color': '#000019',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.00019047619047619048,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '394 BCE-304 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -304,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169988',
#   'dateoffirstpageview': '2012-04-25',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2398',
#   'labeltext': None,
#   'datebegin': -394,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169988,
#   'techniqueid': 7320,
#   'dimensions': '6.82 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169988',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-01-13',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 9,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 4,
#   'rank': 2695,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '12',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'tetradrachm',
#     'dateonobject': None}},
#   'id': 169989,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Hellenistic period',
#   'images': [{'date': '2004-07-12',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141659,
#     'idsid': 18734886,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02262',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02262_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734886',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 9,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02262_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 624,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Tetradrachm of Kyme',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.792952380952381,
#     'css3': '#000000'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.12085714285714286,
#     'css3': '#696969'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.08495238095238095,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.001238095238095238,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '165 BCE-135 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -135,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169989',
#   'dateoffirstpageview': '2009-08-25',
#   'century': '2nd century BCE',
#   'objectnumber': '1.1965.2228',
#   'labeltext': None,
#   'datebegin': -165,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169989,
#   'techniqueid': 7320,
#   'dimensions': '16.08 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169989',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-10-24',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 3,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 6,
#   'rank': 2417,
#   'details': {'coins': {'reverseinscription': 'ΜΕΓ and two monograms',
#     'dieaxis': '2',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'hemidrachm',
#     'dateonobject': None}},
#   'id': 169990,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Hellenistic period, Late',
#   'images': [{'date': '2004-07-07',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141588,
#     'idsid': 18734610,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN01985',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN01985_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734610',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 3,
#   'accessionyear': None,
#   'standardreferencenumber': 'cf. BCD Pelop 1553, 1558',
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN01985_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 345,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obverse: Laureate head of Zeus l. \r\n\r\nReverse: Pan seated on rock and holding lagobolon with eagle on knee',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Hemidrachm of Megalopolis',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.832952380952381,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.1179047619047619,
#     'css3': '#696969'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.04114285714285714,
#     'css3': '#696969'},
#    {'color': '#967d7d',
#     'spectrum': '#955ba5',
#     'hue': 'Brown',
#     'percent': 0.006571428571428572,
#     'css3': '#808080'},
#    {'color': '#af9696',
#     'spectrum': '#ae5596',
#     'hue': 'Brown',
#     'percent': 0.001142857142857143,
#     'css3': '#bc8f8f'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.00028571428571428574,
#     'css3': '#000000'}],
#   'provenance': 'SNG Lockett 2524. Glendining, 27 May 1959 (Lockett), 2000.',
#   'groupcount': 0,
#   'dated': '80-50 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -50,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169990',
#   'dateoffirstpageview': '2015-11-06',
#   'century': '1st century BCE',
#   'objectnumber': '1.1965.1950',
#   'labeltext': None,
#   'datebegin': -80,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169990,
#   'techniqueid': 7320,
#   'dimensions': '2.51 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169990',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-07-03',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 10,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 7,
#   'rank': 2813,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': None,
#     'metal': 'EL',
#     'obverseinscription': None,
#     'denomination': 'twenty-fourth stater',
#     'dateonobject': None}},
#   'id': 169991,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Orientalizing period',
#   'images': [{'date': '2004-07-14',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141691,
#     'idsid': 18734016,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02392',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02392_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734016',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 14,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02392_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 5245,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Electrum',
#   'lendingpermissionlevel': 0,
#   'title': 'Stater of Western Asia Minor, Uncertain Mint',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9776190476190476,
#     'css3': '#000000'},
#    {'color': '#967d4b',
#     'spectrum': '#7fc241',
#     'hue': 'Brown',
#     'percent': 0.007904761904761904,
#     'css3': '#a0522d'},
#    {'color': '#7d644b',
#     'spectrum': '#b25593',
#     'hue': 'Yellow',
#     'percent': 0.007047619047619047,
#     'css3': '#696969'},
#    {'color': '#644b32',
#     'spectrum': '#59ba4a',
#     'hue': 'Brown',
#     'percent': 0.0032380952380952383,
#     'css3': '#556b2f'},
#    {'color': '#af967d',
#     'spectrum': '#c25687',
#     'hue': 'Brown',
#     'percent': 0.003142857142857143,
#     'css3': '#bc8f8f'},
#    {'color': '#000019',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.0007619047619047619,
#     'css3': '#000000'},
#    {'color': '#c8af96',
#     'spectrum': '#e66c64',
#     'hue': 'Brown',
#     'percent': 0.00028571428571428574,
#     'css3': '#d2b48c'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '630 BCE-600 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -600,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169991',
#   'dateoffirstpageview': '2011-01-25',
#   'century': '7th century BCE',
#   'objectnumber': '1.1965.2346',
#   'labeltext': None,
#   'datebegin': -630,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169991,
#   'techniqueid': 7320,
#   'dimensions': '0.58 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169991',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': None,
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 0,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 4,
#   'rank': 2821,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': None,
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'hemidrachm',
#     'dateonobject': None}},
#   'id': 169992,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Early',
#   'images': [{'date': '2004-07-14',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 38909,
#     'idsid': 18734027,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02403',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02403_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734027',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 0,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02403_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 906,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Hemidrachm of Lindos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.940952380952381,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.05828571428571429,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0006666666666666666,
#     'css3': '#000000'},
#    {'color': '#000019',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 9.523809523809524e-05,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': 'c. 510 BCE-490 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -490,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169992',
#   'dateoffirstpageview': None,
#   'century': '6th-5th century BCE',
#   'objectnumber': '1.1965.2354',
#   'labeltext': None,
#   'datebegin': -510,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169992,
#   'techniqueid': 7320,
#   'dimensions': '1.99 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169992',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-11-21',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 20,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 5,
#   'rank': 2822,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': None,
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'double siglos',
#     'dateonobject': None}},
#   'id': 169993,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Classical period, Early',
#   'images': [{'date': '2004-07-14',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141694,
#     'idsid': 18734028,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02404',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02404_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734028',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 23,
#   'accessionyear': None,
#   'standardreferencenumber': 'Konuk',
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02404_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 906,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obverse: Forepart of lion left; on shoulder O\r\nReverse: Incuse square',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Double Siglos of Mylasa (Caria)',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.8552380952380952,
#     'css3': '#000000'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.07942857142857143,
#     'css3': '#696969'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.06266666666666666,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.002285714285714286,
#     'css3': '#000000'},
#    {'color': '#000019',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.00038095238095238096,
#     'css3': '#000000'}],
#   'provenance': 'Helbing, 9 April 1913 lot 588',
#   'groupcount': 0,
#   'dated': '540 - 520 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -495,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169993',
#   'dateoffirstpageview': '2012-10-10',
#   'century': '6th century BCE',
#   'objectnumber': '1.1965.2355',
#   'labeltext': None,
#   'datebegin': -505,
#   'culture': 'Greek',
#   'exhibitioncount': 1,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169993,
#   'techniqueid': 7320,
#   'dimensions': '11.07 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169993',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2015-11-12',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 1,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 2,
#   'rank': 2607,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': None,
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'hemidrachm',
#     'dateonobject': None}},
#   'id': 169994,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late, to Early Hellenistic',
#   'images': [{'date': '2004-07-09',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 51391,
#     'idsid': 18734797,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02173',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02173_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734797',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 1,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02173_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 484,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Hemidrachm of Chalcedon',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9989523809523809,
#     'css3': '#000000'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0010476190476190477,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '350 BCE-300 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -300,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169994',
#   'dateoffirstpageview': '2015-11-12',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2140',
#   'labeltext': None,
#   'datebegin': -350,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169994,
#   'techniqueid': 7320,
#   'dimensions': '2.54 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169994',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2013-07-07',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 1,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 6,
#   'rank': 2795,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '3',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'drachm',
#     'dateonobject': None}},
#   'id': 169995,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Hellenistic period',
#   'images': [{'date': '2004-07-14',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 51436,
#     'idsid': 18733992,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02368',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02368_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18733992',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 1,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02368_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 624,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Drachm of Chios',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.7727619047619048,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.10552380952380952,
#     'css3': '#696969'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.10485714285714286,
#     'css3': '#696969'},
#    {'color': '#967d7d',
#     'spectrum': '#955ba5',
#     'hue': 'Brown',
#     'percent': 0.014476190476190476,
#     'css3': '#808080'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0018095238095238095,
#     'css3': '#000000'},
#    {'color': '#000019',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.0005714285714285715,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '190 BCE-84 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -84,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169995',
#   'dateoffirstpageview': '2013-07-07',
#   'century': '2nd-1st century BCE',
#   'objectnumber': '1.1965.2328',
#   'labeltext': None,
#   'datebegin': -190,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169995,
#   'techniqueid': 7320,
#   'dimensions': '3.61 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169995',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2022-08-02',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 29,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 2,
#   'rank': 2407,
#   'details': {'coins': {'reverseinscription': 'ΚΛΗ',
#     'dieaxis': '9',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'hemidrachm',
#     'dateonobject': None}},
#   'id': 169996,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Hellenistic period, Early',
#   'images': [{'date': '2004-07-06',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 101297,
#     'idsid': 18734600,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN01975',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN01975_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734600',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 68,
#   'accessionyear': None,
#   'standardreferencenumber': 'BMC 4-5; cf. BCD Pelop 1431',
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN01975_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 352,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obverse: Radiate head of Helios facing\r\n\r\nReverse: Bull butting r. Above, centaur galloping r. and brandishing branch.',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Hemidrachm of Cleitor',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9994285714285714,
#     'css3': '#000000'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0005714285714285715,
#     'css3': '#000000'}],
#   'provenance': 'Acq. Hamburger, 1930.',
#   'groupcount': 0,
#   'dated': '350-260 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -260,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169996',
#   'dateoffirstpageview': '2011-10-17',
#   'century': '4th-3rd century BCE',
#   'objectnumber': '1.1965.1940',
#   'labeltext': None,
#   'datebegin': -350,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169996,
#   'techniqueid': 7320,
#   'dimensions': '2.76 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169996',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2017-09-26',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 4,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 6,
#   'rank': 2665,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '9',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'tetrobol',
#     'dateonobject': None}},
#   'id': 169997,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-12',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141645,
#     'idsid': 18734828,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02204',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02204_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734828',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 6,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02204_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Tetrobol of Lampsakos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#191919',
#     'spectrum': '#1eb264',
#     'hue': 'Grey',
#     'percent': 0.8031428571428572,
#     'css3': '#000000'},
#    {'color': '#646464',
#     'spectrum': '#7866ad',
#     'hue': 'Grey',
#     'percent': 0.15361904761904763,
#     'css3': '#696969'},
#    {'color': '#4b4b4b',
#     'spectrum': '#3db657',
#     'hue': 'Grey',
#     'percent': 0.02495238095238095,
#     'css3': '#2f4f4f'},
#    {'color': '#323232',
#     'spectrum': '#2eb45d',
#     'hue': 'Grey',
#     'percent': 0.01685714285714286,
#     'css3': '#2f4f4f'},
#    {'color': '#afafaf',
#     'spectrum': '#8c5fa8',
#     'hue': 'Grey',
#     'percent': 0.0010476190476190477,
#     'css3': '#a9a9a9'},
#    {'color': '#c8c8c8',
#     'spectrum': '#8c5fa8',
#     'hue': 'Grey',
#     'percent': 0.00038095238095238096,
#     'css3': '#c0c0c0'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '366 BCE-333 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -333,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169997',
#   'dateoffirstpageview': '2013-08-18',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2198',
#   'labeltext': None,
#   'datebegin': -366,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169997,
#   'techniqueid': 7320,
#   'dimensions': '2.19 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169997',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2016-10-18',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 4,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 7,
#   'rank': 2711,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '12',
#     'metal': 'EL',
#     'obverseinscription': None,
#     'denomination': 'hekte',
#     'dateonobject': None}},
#   'id': 169998,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-13',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 101375,
#     'idsid': 18734917,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02293',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02293_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734917',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 4,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02293_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Electrum',
#   'lendingpermissionlevel': 0,
#   'title': 'Hekte of Lesbos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9428571428571428,
#     'css3': '#000000'},
#    {'color': '#4b4b32',
#     'spectrum': '#4ab851',
#     'hue': 'Green',
#     'percent': 0.021714285714285714,
#     'css3': '#556b2f'},
#    {'color': '#7d644b',
#     'spectrum': '#b25593',
#     'hue': 'Yellow',
#     'percent': 0.019238095238095238,
#     'css3': '#696969'},
#    {'color': '#7d7d64',
#     'spectrum': '#6cbd45',
#     'hue': 'Yellow',
#     'percent': 0.011333333333333334,
#     'css3': '#808080'},
#    {'color': '#af967d',
#     'spectrum': '#c25687',
#     'hue': 'Brown',
#     'percent': 0.0032380952380952383,
#     'css3': '#bc8f8f'},
#    {'color': '#c8af96',
#     'spectrum': '#e66c64',
#     'hue': 'Brown',
#     'percent': 0.0013333333333333333,
#     'css3': '#d2b48c'},
#    {'color': '#c8c8af',
#     'spectrum': '#b55592',
#     'hue': 'Green',
#     'percent': 0.00028571428571428574,
#     'css3': '#c0c0c0'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '377 BCE-326 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -326,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169998',
#   'dateoffirstpageview': '2014-04-23',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2244',
#   'labeltext': None,
#   'datebegin': -377,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169998,
#   'techniqueid': 7320,
#   'dimensions': '2.55 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169998',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2015-11-12',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 3,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 6,
#   'rank': 2712,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '6',
#     'metal': 'EL',
#     'obverseinscription': None,
#     'denomination': 'hekte',
#     'dateonobject': None}},
#   'id': 169999,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-13',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 38881,
#     'idsid': 18734918,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02294',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02294_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734918',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 3,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02294_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Electrum',
#   'lendingpermissionlevel': 0,
#   'title': 'Hekte of Lesbos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9437142857142857,
#     'css3': '#000000'},
#    {'color': '#967d64',
#     'spectrum': '#b65590',
#     'hue': 'Brown',
#     'percent': 0.023047619047619046,
#     'css3': '#808080'},
#    {'color': '#7d644b',
#     'spectrum': '#b25593',
#     'hue': 'Yellow',
#     'percent': 0.021904761904761906,
#     'css3': '#696969'},
#    {'color': '#af967d',
#     'spectrum': '#c25687',
#     'hue': 'Brown',
#     'percent': 0.00780952380952381,
#     'css3': '#bc8f8f'},
#    {'color': '#c8af96',
#     'spectrum': '#e66c64',
#     'hue': 'Brown',
#     'percent': 0.0021904761904761906,
#     'css3': '#d2b48c'},
#    {'color': '#c8c8af',
#     'spectrum': '#b55592',
#     'hue': 'Green',
#     'percent': 0.0013333333333333333,
#     'css3': '#c0c0c0'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '377 BCE-326 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -326,
#   'url': 'https://www.harvardartmuseums.org/collections/object/169999',
#   'dateoffirstpageview': '2014-04-23',
#   'century': '4th century BCE',
#   'objectnumber': '1.1965.2245',
#   'labeltext': None,
#   'datebegin': -377,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 169999,
#   'techniqueid': 7320,
#   'dimensions': '2.54 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/169999',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2016-10-18',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 2,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 8,
#   'rank': 2713,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '12',
#     'metal': 'EL',
#     'obverseinscription': None,
#     'denomination': 'hekte',
#     'dateonobject': None}},
#   'id': 170000,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Classical period, Late',
#   'images': [{'date': '2004-07-13',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 141667,
#     'idsid': 18734919,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02295',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02295_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734919',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 3,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02295_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 618,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Electrum',
#   'lendingpermissionlevel': 0,
#   'title': 'Hekte of Lesbos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.938,
#     'css3': '#000000'},
#    {'color': '#967d64',
#     'spectrum': '#b65590',
#     'hue': 'Brown',
#     'percent': 0.020095238095238097,
# ...
#   'medium': 'Bronze',
#   'lendingpermissionlevel': 0,
#   'title': 'Coin of Oea under Tiberius',
#   'accessionmethod': 'Gift',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 1,
#     'css3': '#000000'}],
#   'provenance': 'Purchased from Schulz',
#   'groupcount': 0,
#   'dated': '14-37',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': 37,
#   'people': [{'role': 'Coin Constituent',
#     'birthplace': None,
#     'gender': 'male',
#     'displaydate': 'r. 14-37 CE',
#     'prefix': None,
#     'culture': 'Roman',
#     'displayname': 'Tiberius',
#     'alphasort': 'Tiberius',
#     'name': 'Tiberius',
#     'personid': 19546,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/170121',
#   'dateoffirstpageview': '2011-03-14',
#   'century': '1st century CE',
#   'objectnumber': '1982.100.114',
#   'labeltext': None,
#   'datebegin': 14,
#   'culture': 'Roman Provincial',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 170121,
#   'techniqueid': 7320,
#   'dimensions': '14.78 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/170121',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-03-22',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 5,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 3,
#   'rank': 2559,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': '6',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'stater',
#     'dateonobject': None}},
#   'id': 170158,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': 'Hellenistic period, Early',
#   'images': [{'date': '2004-07-09',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 101331,
#     'idsid': 18734752,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02128',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02128_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734752',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 8,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02128_dynmc',
#   'titlescount': 1,
#   'peoplecount': 0,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 352,
#   'technique': 'Struck',
#   'edition': None,
#   'description': None,
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Stater of Praesos',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9224761904761904,
#     'css3': '#000000'},
#    {'color': '#7d6464',
#     'spectrum': '#8e5ea7',
#     'hue': 'Brown',
#     'percent': 0.07657142857142857,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0009523809523809524,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '300 BCE-270 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -270,
#   'url': 'https://www.harvardartmuseums.org/collections/object/170158',
#   'dateoffirstpageview': '2012-10-10',
#   'century': '3rd century BCE',
#   'objectnumber': '1.1965.2092',
#   'labeltext': None,
#   'datebegin': -300,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 170158,
#   'techniqueid': 7320,
#   'dimensions': '11.19 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/170158',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-10-27',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 30,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 3,
#   'rank': 3180,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': None,
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'siglos',
#     'dateonobject': None}},
#   'id': 170159,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Classical period',
#   'images': [{'date': '2004-07-21',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 101876,
#     'idsid': 18734383,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02761',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02761_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734383',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 30,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02761_dynmc',
#   'titlescount': 1,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 1419,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obv.: King running to r., kneeling, holding bow and spear\r\nRev.: incuse punch',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Siglos of the Achaemenid Kings',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9477142857142857,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.05095238095238095,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0013333333333333333,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '490 BCE-400 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -400,
#   'people': [{'role': 'Coin Constituent',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'r. c. 522-330 BCE',
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Achaemenid Kings',
#     'alphasort': 'Achaemenid Kings',
#     'name': 'Achaemenid Kings',
#     'personid': 20115,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/170159',
#   'dateoffirstpageview': '2012-09-24',
#   'century': '5th century BCE',
#   'objectnumber': '1.1965.2713',
#   'labeltext': None,
#   'datebegin': -490,
#   'culture': 'Persian',
#   'exhibitioncount': 1,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 170159,
#   'techniqueid': 7320,
#   'dimensions': '5.26 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/170159',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-09-29',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 70,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 3,
#   'rank': 3242,
#   'details': {'coins': {'reverseinscription': 'PTOLEMAIOU BASILEOS',
#     'dieaxis': '12',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'tetradrachm',
#     'dateonobject': 'Year 2'}},
#   'id': 170160,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Ptolemaic period',
#   'images': [{'date': '2004-07-21',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 39010,
#     'idsid': 18735274,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02819',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02819_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18735274',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 94,
#   'accessionyear': None,
#   'standardreferencenumber': 'Morkholm, MN 20; Svoronos 1817',
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02819_dynmc',
#   'titlescount': 1,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 1623,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obv.: Diademed head of Ptolemy I r. Border of dots.\r\nRev.: Eagle standing on thunderbolt l., Border of dots.',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Tetradrachm of Kleopatra VII, Alexandria',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9000952380952381,
#     'css3': '#000000'},
#    {'color': '#644b4b',
#     'spectrum': '#8362aa',
#     'hue': 'Brown',
#     'percent': 0.09828571428571428,
#     'css3': '#696969'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0016190476190476191,
#     'css3': '#000000'}],
#   'provenance': None,
#   'groupcount': 0,
#   'dated': '51 -50  BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -50,
#   'people': [{'role': 'Coin Constituent',
#     'birthplace': None,
#     'gender': 'female',
#     'displaydate': 'r. 51-30 BCE',
#     'prefix': None,
#     'culture': 'Greek',
#     'displayname': 'Cleopatra VII',
#     'alphasort': 'Cleopatra VII',
#     'name': 'Cleopatra VII',
#     'personid': 20161,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/170160',
#   'dateoffirstpageview': '2013-01-29',
#   'century': '1st century BCE',
#   'objectnumber': '1.1965.2775',
#   'labeltext': None,
#   'datebegin': -51,
#   'culture': 'Greek',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 170160,
#   'techniqueid': 7320,
#   'dimensions': '13.45 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/170160',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Arthur M. Sackler Museum, Loan from the Trustees of the Arthur Stone Dewing Greek Numismatic Foundation',
#   'accesslevel': 1,
#   'createdate': '2001-08-28T00:00:00-04:00',
#   'dateoflastpageview': '2025-11-09',
#   'classificationid': 50,
#   'division': 'Asian and Mediterranean Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 56,
#   'contact': 'am_asianmediterranean@harvard.edu',
#   'colorcount': 2,
#   'rank': 3181,
#   'details': {'coins': {'reverseinscription': None,
#     'dieaxis': 'not assignable',
#     'metal': 'AR',
#     'obverseinscription': None,
#     'denomination': 'siglos',
#     'dateonobject': None}},
#   'id': 170161,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': 'Classical period',
#   'images': [{'date': '2004-07-21',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 101877,
#     'idsid': 18734384,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'COIN02762',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02762_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/18734384',
#     'height': 478}],
#   'worktypes': [{'worktypeid': '100', 'worktype': 'coin'}],
#   'imagecount': 1,
#   'totalpageviews': 70,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Coins',
#   'relatedcount': 0,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:COIN02762_dynmc',
#   'titlescount': 1,
#   'peoplecount': 2,
#   'style': None,
#   'lastupdate': '2025-12-11T04:32:30-05:00',
#   'commentary': None,
#   'periodid': 1419,
#   'technique': 'Struck',
#   'edition': None,
#   'description': 'Obv.: King running to r., kneeling, holding bow and spear\r\nRev.: incuse punch',
#   'medium': 'Silver',
#   'lendingpermissionlevel': 0,
#   'title': 'Siglos of the Achaemenid Kings',
#   'accessionmethod': 'Not Recorded',
#   'colors': [{'color': '#000000',
#     'spectrum': '#1eb264',
#     'hue': 'Black',
#     'percent': 0.9989523809523809,
#     'css3': '#000000'},
#    {'color': '#190000',
#     'spectrum': '#2eb45d',
#     'hue': 'Black',
#     'percent': 0.0010476190476190477,
#     'css3': '#000000'}],
#   'provenance': 'Elder, 24 Nov. 1928, 878',
#   'groupcount': 0,
#   'dated': '520 - 480 BCE',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'dateend': -480,
#   'people': [{'role': 'Coin Constituent',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'r. c. 522-330 BCE',
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Achaemenid Kings',
#     'alphasort': 'Achaemenid Kings',
#     'name': 'Achaemenid Kings',
#     'personid': 20115,
#     'deathplace': None,
#     'displayorder': 1},
#    {'role': 'Coin Constituent',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'r. 522 - 480 BCE',
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Darius I, the Great',
#     'alphasort': 'Darius I',
#     'name': 'Darius I, the Great',
#     'personid': 59658,
#     'deathplace': None,
#     'displayorder': 2}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/170161',
#   'dateoffirstpageview': '2012-09-24',
#   'century': '5th century BCE',
#   'objectnumber': '1.1965.2714',
#   'labeltext': None,
#   'datebegin': -520,
#   'culture': 'Persian',
#   'exhibitioncount': 1,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 170161,
#   'techniqueid': 7320,
#   'dimensions': '5.39 g',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/170161',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]}]

# %% [markdown]
# ##2500 records needs to be collected for each artifacts

# %%
type(data["records"])
# Out:
# list

# %% [markdown]
# ######*Artifacts* -
#
# *    METADATA
# *    MEDIA
# *    COLORS

# %%
metadata = []
media = []
colors = []
num_pages_to_fetch = 25
records=[]
for page in range(1, num_pages_to_fetch + 1):
  for i in data['records']:
     metadata.append(dict(
         id = i['id'],
         title = i['title'],
         culture = i['culture'],
         period = i['period'],
         century = i['century'],
         medium = i['medium'],
         dimensions = i['dimensions'],
         description = i['description'],
         department = i['department'],
         classification = i['classification'],
         accessionyear = i['accessionyear'],
         accessionmethod = i['accessionmethod']
     ))

     media.append(dict(
         objectid = i['objectid'],
         imagecount = i['imagecount'],
         mediacount = i['mediacount'],
         colorcount = i['colorcount'],
         rank = i['rank'],
         datebegin = i['datebegin'],
         dateend = i['dateend']
     ))
     color_details = i.get('colors')
     if color_details:
         for j in color_details:
              colors.append(dict(
                  objectid = i['objectid'],
                  color = j['color'],
                  spectrum = j['spectrum'],
                  hue = j['hue'],
                  percent = j['percent'],
                  css3 = j['css3']
              ))

# %% [markdown]
# ###*artifact_metadata record and length*

# %%
#metadata api record is a list of dictionaries
metadata
# Out:
# [{'id': 322691,
#   'title': 'Coin of Trajan, Sepphoris',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st-2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.44g',
#   'description': 'Obv.: laureate bust, r., around Greek inscription\r\nRev.: paalm-tree with two bunches of dates, below Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322692,
#   'title': 'Coin of Tiberias under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '2.58g',
#   'description': 'Obverse: Laureate head of Trajan, r., around Greek inscription\r\nReverse: anchor, around Greek inscription.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322693,
#   'title': 'Coin of Sepphoris- Diocaesarea under Antoninus (?)',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.36g\r\n',
#   'description': 'Obv.: Draped head of Antoninus Pius r., around Greek inscription\r\nRev.: City-goddess standing r. in tetrastyle temple with central arch, resting l. hand on scepter and holding cornucopia with r., around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322694,
#   'title': 'Coin of  Petra under Elagabulus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '7.47g',
#   'description': 'Obv.: head, r., around Greek inscription\r\nRev.: bull, r., around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322695,
#   'title': 'Coin of Aelia Capitolina under Commodus(?)',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '7.71g',
#   'description': 'Obv.: head to r., around inscription\r\nRev.: Tyche standing l., holding object and resting on scepter, around inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322696,
#   'title': 'Coin of Dora under Nero',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.91g',
#   'description': 'Obv.: Head of Doros, r.\r\nRev.: Tyche standing facing looking r.,holding standard and cornucopia, around Greek inscription and date.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322697,
#   'title': 'Coin of Akko-Ptolemais under Elagabulus (?)',
#   'culture': 'Roman',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.93g',
#   'description': 'Obv.: draped head of Elagabulus r., laureate, around Latin inscription\r\nRev.: Tyche in tetrastyle building under arch, facing l., holding cornucopia, to r. smal victory standing on column, below, Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322698,
#   'title': 'Coin of Akko-Ptolemais under Valerian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Late',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.46g',
#   'description': 'Obv.: draped laureate head of Valerian, l., around Latin inscription\r\nRev.: Sacred tree flanked by two altars with snakes; in r. field, caduceus, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322699,
#   'title': 'Coin of Neapolis under Philip II',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Late',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '16.05g',
#   'description': "Obv.: Laureate head of Philip II, r., around Latin inscription\r\nRev.: Emperor as founder plowing with bull and cow r., above animals' heads, a small standard, above, Mount Gerizim, around, Latin inscription",
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322700,
#   'title': 'Coin of Dora under Vespasian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Early',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.92g',
#   'description': 'Obv.: Head of Vespasian r., laureate.\r\nRev.: Tyche wearing turreted crown and long chiton, standing to front, head r., in l. cornucopiae, in r. standard, on r. downwards inscr., in field l. date.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322701,
#   'title': 'Coin of Ascalon under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.72g',
#   'description': 'Obv.: laureate head of Trajan r., around Greek inscription\r\nRev.: Rev.: Tyche standing on prow of galley l., holding standard and aphlaston, on l., altar, in r. field, dove and date, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322702,
#   'title': 'Coin of Ascalon under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.96g',
#   'description': 'Obv.: laureate head of Trajan, r., around Greek inscription\r\nRev.: Ascalon god Phanebal standing facing with short military dress looking r., holding dagger and palm branch with shield, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322703,
#   'title': 'Trajan, one of three pieces',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.75g',
#   'description': 'Obv.: laureate head of Trajan, around Greek inscription\r\nRev.: Rev.: Rev.: Tyche standing on prow of galley l., holding standard and aphlaston, on l., altar, in r. field, dove and date, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322704,
#   'title': 'Coin of Tiberias under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st-2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '17.53g',
#   'description': 'Obv.: laureate head of Trajan r., around Greek inscription\r\nRev.: Tyche standing facing, looking l., holding cornucopia and resting on rudder, at her feet, prow of galley, around Greek inscription, in field date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322705,
#   'title': 'Coin of Ascalon under Antoninus Pius',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.2 g\r\n1.9 cm (3/4 in.)',
#   'description': 'Obv.: laureate head of Antoninus Pius, around Greek inscription\r\nRev.: Ascalon god Phanebal standing facing with short military dress looking r., holding dagger and palm branch with shield, on l. Greek inscription, on r. date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322706,
#   'title': 'Coin of Ascalon under Antoninus Pius',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '13.6 g\r\n2.7 cm (1 1/16 in.)',
#   'description': 'Obv.: laureate head of Antoninus Pius r., around Greek inscription\r\nRev.: Atargatis standing on Triton, holding cornucopia, dove, and scepter, Greek inscription on l., on r. date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322707,
#   'title': 'Coin of Ascalon under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '11 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: laureate head of Trajan, r., around Greek inscription\r\nRev.: Tyche standing on prow of galley l., holding standard and aphlaston, on l., altar and Greek inscription, on r., dove and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322708,
#   'title': 'Coin of Ascelon under Domitian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.8 g\r\n1.9 cm (3/4 in.)',
#   'description': 'Obv.: laureate head of Domitian r., around Greek inscription\r\nRev.: Ascelon god Phanebal standing facing with short military dress looking r., holding dagger and palm branch with shield, on right Greek inscription, on l. date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322709,
#   'title': 'Domitian, one of three pieces',
#   'culture': None,
#   'period': 'Roman Imperial period',
#   'century': None,
#   'medium': None,
#   'dimensions': '12.3 g\r\n2.2 cm (7/8 in.)',
#   'description': None,
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322710,
#   'title': 'Coin of Ascalon under Macrinus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '11.2 g\r\n2.5 cm (1 in.)',
#   'description': 'Obv.: draped laureate  head of Macrinus, r., around Greek inscription\r\nRev.: Atargatis standing on Triton, holding cornucopia, dove, and scepter, on l. Greek inscription, on r., date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322711,
#   'title': 'Coin of Ascalon',
#   'culture': 'Roman Provincial',
#   'period': None,
#   'century': '1st century BCE-1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.8 g\r\n1.7 cm (11/16 in.)',
#   'description': 'Obv.: Head of Tyche r.\r\nRev.: Galley with ram and aphlaston l.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322712,
#   'title': 'Coin of Ascalon under Domitian',
#   'culture': 'Roman Provincial',
#   'period': None,
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.5 g\r\n2.3 cm (15/16 in.)',
#   'description': 'Obv.: laureate head of Domitian r., around Greek inscription\r\nRev.: Tyche standing on prow of galley l., holding standard and aphlaston;, on l., altar and Greek inscription, on r., dove and date.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322713,
#   'title': 'Coin of Aelia Capitolina under M. Aurelius & Commodus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '13.5 g\r\n2.7 cm (1 1/16 in.)',
#   'description': 'Obv.: laureate heads of Marcus Aurelius on l. and Commodus on r., confronted, around Latin inscription\r\nRev.: head of Serapis r., around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322714,
#   'title': 'Coin of Aelia Capitolina under Elagabalus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '9.2 g\r\n2.3 cm (7/8 in.)',
#   'description': 'Obv.: laureate draped head of Elagabalus r., around Latin inscription\r\nRev.: The stone of Emesa with eagle relief carried on quadriga facing, each pair of horses is shaded by a canopy, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322715,
#   'title': 'Coin of Neapolis under Philip I',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '13.3 g\r\n2.7 cm (1 1/16 in.)',
#   'description': 'Obv.: radiate head of Philip I r., around Latin inscription\r\nRev.: She-wolf standing l,m head turned at Romulus and Remus suckling, above, Mount Gerizim, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322716,
#   'title': 'Coin of Aelia Capitolina under Elagabalus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': None,
#   'dimensions': '6.1 g\r\n2.2 cm (7/8 in.)',
#   'description': 'Obv.: laureate head of Elagabalus r., around Latin inscription\r\nRev.: stone of Emesa carried on a quadriga facing, each pair of horses is shaded by a canopy, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322717,
#   'title': 'Coin of Aelia Capitolina under Alexander Severus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.4 g\r\n2.2 cm (7/8 in.)',
#   'description': 'Obv.: laureate bust of Alexander Severus r., around Latin inscription\r\nRev.: Tyche seated on throne l., holding cornucopia and bowl',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322718,
#   'title': 'Coin of Aelia Capitolina under Herennius Etruscus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '14.8 g\r\n2.7 cm (1 1/16 in.)',
#   'description': 'Obv.: radiate head of Herennius Etruscus r., around Latin inscription\r\nRev.: boar running r., on his back, legionary eagle with vexillum topped bby start, in it letters, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322719,
#   'title': 'Coin of Bostra under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '7.5 g\r\n2 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Greek inscription\r\nRev.: head of Arabia r., holding in each arm small figure of seated child, below, Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322720,
#   'title': 'Coin of Caesarea under Caracalla',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd-3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '14.2 g\r\n2.3 cm (7/8 in.)',
#   'description': 'Obv.: laureate head of Caracalla r., around Latin inscription\r\nRev.: head of Serapis, r., around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322721,
#   'title': 'Coin of Caesarea under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '19 g\r\n2.9 cm (1 1/8 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Latin inscription\r\nRev.: emperor as founder plowing r. with ox and cow; above, Victory flying l. to crown him with wreath, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322976,
#   'title': 'Coin of Caesarea under Trajan Decius',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.7 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Trajan Decius r., around Latin inscription\r\nRev.: altar, behind it, palm tree and olive tree, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322978,
#   'title': 'Coin of Caesarea Panias',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.1 g\r\n1.9 cm (3/4 in.)',
#   'description': 'Obv.: temple with two columns, around Latin inscription\r\nRev.: temple with six columns, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322979,
#   'title': 'Coin of Gaza under Elagabalus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.4 g\r\n2 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Elagabalus r., around Greek inscription\r\nRev.: Tyche wearing kalathos standing facing looking l., resting her hand on scepter and holding cornucopia, beside her, heifer standing l., in r. field, symbol and date, on l., Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322980,
#   'title': 'Coin of Gadara',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Republican period',
#   'century': '1st century BCE',
#   'medium': 'Bronze',
#   'dimensions': '3.8 g\r\n1.9 cm (3/4 in.)',
#   'description': 'Obv.: veiled head of Tyche r., above shoulder, palm branch\r\nRev.: cornucopia, around Greek inscription and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322981,
#   'title': 'Coin of Gadara',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Republican period',
#   'century': '1st century BCE',
#   'medium': 'Bronze',
#   'dimensions': '3 g\r\n1.7 cm (11/16 in.)',
#   'description': 'Obv.: veiled head of Tyche r., above shoulder, palm branch\r\nRev.: cornucopia, around Greek inscription and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322982,
#   'title': 'Coin of Dora under Vespasian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '10 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: head of Doros r., border of dots\r\nRev.: Tyche standing facing r., holding standard and cornucopia, on l., date, around border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322983,
#   'title': 'Coin of Gaza under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Greek inscription\r\nRev.: Tyche wearing kalathos standing facing looking l., resting her hadn on scepter and holding cornucopia, beside her, heifer standing l., around Greek inscription, symbol, and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322984,
#   'title': 'Coin of Gaza under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.3 g\r\n1.8 cm (11/16 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Greek inscription\r\nRev.: Herakles, nude, standing facing, looking l., resting on club and holding lion skin, around Greek inscription, date, and symbol',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322985,
#   'title': 'Coin of Gaba under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '9.8 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Greek inscription\r\nRev.: Victory advancing l., holding wreath and trophy, around Greek inscription and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322986,
#   'title': 'Coin of Gaza under Hadrian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.7 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Hadrian r., around Greek inscription\r\nRev.: Tyche wearing kalathos standing facing looking l., resting her hand on scepter and holding cornucopia, beside her, heifer standing l., around Greek inscription, date, and symbol',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322987,
#   'title': 'Coin of Gaza under Antoninus Pius',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '24.5 g\r\n2.9 cm (1 1/8 in.)',
#   'description': 'Obv.: laureate head of Antoninus Pius r., around Greek inscription\r\nRev.: Bust of Tyche, with city crown with details of towers and gates, veiled, around Greek inscription, symbol, and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322988,
#   'title': 'Coin of Gaza under Septimus Severus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: laureate heaad of Septimus Severus r., around Greek inscription\r\nRev.: Io and Tyche standing facing one another, shaking hands, between them symbol, around, Greek inscription and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322989,
#   'title': 'Coin of Gaza under Julia Domna',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.6 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: head of Julia Domna r., around Greek inscription\r\nRev.: Marnas and Artemis is distyle facade, around Greek inscription, symbol, and date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322990,
#   'title': 'Coin of Gaza under Hadrian',
#   'culture': 'Roman Imperial',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.9 g\r\n1.5 cm (5/8 in.)',
#   'description': 'Obv.: Minos standing facing looking l., holding long branch and spear, on right Greek inscription\r\nRev.: Tree, around Greek inscription, date, and symbol',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322991,
#   'title': 'Coin of Neapolis under Volusian (?)',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '11.2 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: radiate head of Volusian, r.\r\nRev.: eagle carrying Mount Gerizim, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322992,
#   'title': 'Coin of Neapolis under Faustina II',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.7 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: head of Faustina II r., around Greek inscription\r\nRev.: Ephesian Artemis facing resting both hands on fillet-like supports, flanked by two stags, around Greek inscription, in field date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322993,
#   'title': 'Coin of Neapolis under Elagabalus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.7 g\r\n2.2 cm (7/8 in.)',
#   'description': 'Obv.: laureate head of Elagabalus r., around Greek inscription\r\nRev.: view of Mount Gerizim, below in front, a colonnade, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322994,
#   'title': 'Coin of Neapolis under Philip I',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '16 g\r\n2.8 cm (1 1/16 in.)',
#   'description': 'Obv.: laureate head of Philip I r., around Latin inscription\r\nRev.: Mount Gerizim supported by eagle standing with spread wings, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322995,
#   'title': 'Coin of Neapolis under Elagabalus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '11.2 g\r\n1.9 cm (3/4 in.)',
#   'description': 'Obv.: laureate head of Elagabalus r., around Greek inscription, rectangular countermark depicting letter A\r\nRev.: Mount Gerizim, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322996,
#   'title': 'Coin of Neapolis under Philip I',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '13 g\r\n2.3 cm (15/16 in.)',
#   'description': 'Obv.: radiate head of Philip I, around Latin inscription\r\nRev.: on r., helmeted female figure standing l., holding scepter behind lighted altar, looking at Victory carrying mount Gerizim on her arms, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322997,
#   'title': 'Coin of Neapolis under Philip I',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.1 g\r\n2.7 cm (1 1/16 in.)',
#   'description': 'Obv.: radiate head of Philip I r., around Latin inscription\r\nRev.: Latin inscription in wreath',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322998,
#   'title': 'Coin of Nysa Scythopolis under Gordian III',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Late',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12 g\r\n2.3 cm (7/8 in.)',
#   'description': 'Obv.: laureate head of Gordian III, around Greek inscription\r\nRev.: Dionysus advancing r., pointing thyrsos at small figure on one knee with hands behind; in l. field, panther standing l., in upper r. field, bunch of grapes, around Greek inscription and in field date',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 322999,
#   'title': 'Coin of Neapolis under Elagabulus',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd-3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.8 g\r\n2.2 cm (7/8 in.)',
#   'description': None,
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323000,
#   'title': 'Denarius of Nero, Forgery',
#   'culture': 'Roman',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Silver (?)',
#   'dimensions': '3.2 g\r\n1.8 cm (11/16 in.)',
#   'description': 'Obv.: laureate head of Nero, r., around Latin inscription\r\nRev.: Salus seated l. on throne, r. hand holding patera, l. resting at her side, below Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323001,
#   'title': 'Coin (AE2) of Theodosius I, Antioch',
#   'culture': 'Roman Imperial',
#   'period': 'Roman Imperial period, Late, to Early Byzantine',
#   'century': '4th century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.9 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obverse: Bust of emperor r., draped, cuirassed, with pearl diadem.\r\nReverse: Emperor standing facing r., holding standard and globe, with l. foot on bound captive. ANTA in exergue.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323002,
#   'title': 'Coin of Constantine IX, Constantinople',
#   'culture': 'Byzantine',
#   'period': 'Byzantine period, Middle',
#   'century': '11th century',
#   'medium': 'Silver',
#   'dimensions': '2.2 g\r\n2.5 cm (1 in.)',
#   'description': 'Obv.: emperor in military attire, facing, holding long cross and sword, around Greek inscription\r\nRev.: Virgin Mary, standing facing, orans, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323003,
#   'title': 'Coin of Manuel I',
#   'culture': 'Byzantine',
#   'period': 'Byzantine period',
#   'century': '12th century',
#   'medium': 'Bronze',
#   'dimensions': '3.2 g\r\n2.6 cm (1 1/16 in.)',
#   'description': 'Obv.: Christ seated on throne, Greek to l. and r. \r\nRev.: Manuel facing, being crowned by Mary, around Greek inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323212,
#   'title': 'Coin of Bar Kokhba, Year 1',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '13.69g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, around border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323213,
#   'title': 'Coin of Bar Kokhba, Year 2',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.17g',
#   'description': 'Obv.: Small three-lobed vine leaf hanging on cut branch, around Hebrew inscription, around border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323214,
#   'title': 'Coin of Bar Kokhba, Year 2',
#   'culture': 'Jewish',
#   'period': None,
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '9.65g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, around border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323215,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.89g',
#   'description': 'Obv.: Small three-lobed vine leaf hanging on cut branch, around Hebrew inscription\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323216,
#   'title': 'Coin of Bar Kokhba, Year 2',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.02g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323217,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '11.86g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323218,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '9.91g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323219,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.47g',
#   'description': 'Obv.: Small three-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323220,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.39g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323221,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.55g',
#   'description': 'Obv.: Five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323222,
#   'title': 'Coin of Bar Kochba',
#   'culture': 'Jewish',
#   'period': None,
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.14g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323223,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.89g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323224,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.55g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323225,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.58g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323226,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.65g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323227,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.80g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323228,
#   'title': 'Coin of Ptolemais as colony, under Nero',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Early',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '16.38 g',
#   'description': 'Obv.: laureate head of Nero to r., around Latin inscription\r\nRev.: togate man ploughing with two oxen; behind four vexilla, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323229,
#   'title': 'Coin of Caesarea under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st-2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.7 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Trajan, r., around Latin inscription\r\nRev.: Victory advancing l., holding wreath and palm branch, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323230,
#   'title': 'Coin of Caesarea under Domitian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '10 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: head of Domitian r., around Latin inscription\r\nRev.: Minerva standing on galley to r., holding shield in l. hand and spear in r., on l., trophy, on r., palm branch, between Minerva and prow of galley, small owl',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323231,
#   'title': 'Coin of Caesarea under Domitian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '15 g\r\n2.8 cm (1 1/16 in.)',
#   'description': 'Obv.: radiate head of Domitian r., around Latin inscription, round countermark depicting head to r.\r\nRev.: Palm tree, with seven branches and two clusters of dates, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323640,
#   'title': 'Countermarked As of Nero, Lugdunum',
#   'culture': 'Roman Imperial',
#   'period': 'Roman Imperial period, Early',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.72g',
#   'description': 'Obv.: Laureate head of Nero l.; around, NERO CLAVD CAESAR AVG GERMANICVS. Countermarked S P Q R across lower half of head.\r\nRev.: Victory flying l., holding in both hands shield inscribed [S P Q R]; to l. and r., S-C.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Gift'},
#  {'id': 47107,
#   'title': 'One of Eight Irish Coins Minted in 1928: Farthing',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '2.81 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47583,
#   'title': 'One of Eight Irish Coins Minted in 1928: Florin',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '11.4 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47584,
#   'title': 'One of Eight Irish Coins Minted in 1928: Shilling',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '5.68 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47585,
#   'title': 'One of Eight Irish Coins Minted in 1928: Threepence',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '3.08 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47586,
#   'title': 'One of Eight Irish Coins Minted in 1928: Sixpence',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '4.4 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47587,
#   'title': 'One of Eight Irish Coins Minted in 1928: Penny',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '9.51 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47588,
# ...
#  {'id': 323219,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.47g',
#   'description': 'Obv.: Small three-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323220,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.39g',
#   'description': 'Obv.: Small five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323221,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.55g',
#   'description': 'Obv.: Five-lobed vine leaf hanging on cut branch, around Hebrew inscription, circle of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323222,
#   'title': 'Coin of Bar Kochba',
#   'culture': 'Jewish',
#   'period': None,
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.14g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323223,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '4.89g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323224,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '6.55g',
#   'description': 'Obv.: Bunch of grapes, around Hebrew inscription, border of dots\r\nRev.: Palm tree with seven branches, r. and l. cluster with three fruits each, around border of dots, underneath Hebrew inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323225,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.58g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323226,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.65g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323227,
#   'title': 'Coin of Bar Kokhba',
#   'culture': 'Jewish',
#   'period': 'Roman Imperial period',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '5.80g',
#   'description': 'Obv.: Upright palm branch within laurel wreath, a medallion at the top and ribbon ties at the bottom, around Hebrew inscription, border of dots \r\nRev.: Lyre with three strings, around Hebrew inscription, border of dots',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323228,
#   'title': 'Coin of Ptolemais as colony, under Nero',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Early',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '16.38 g',
#   'description': 'Obv.: laureate head of Nero to r., around Latin inscription\r\nRev.: togate man ploughing with two oxen; behind four vexilla, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323229,
#   'title': 'Coin of Caesarea under Trajan',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st-2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '10.7 g\r\n2.1 cm (13/16 in.)',
#   'description': 'Obv.: laureate head of Trajan, r., around Latin inscription\r\nRev.: Victory advancing l., holding wreath and palm branch, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323230,
#   'title': 'Coin of Caesarea under Domitian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '10 g\r\n2.4 cm (15/16 in.)',
#   'description': 'Obv.: head of Domitian r., around Latin inscription\r\nRev.: Minerva standing on galley to r., holding shield in l. hand and spear in r., on l., trophy, on r., palm branch, between Minerva and prow of galley, small owl',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323231,
#   'title': 'Coin of Caesarea under Domitian',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '15 g\r\n2.8 cm (1 1/16 in.)',
#   'description': 'Obv.: radiate head of Domitian r., around Latin inscription, round countermark depicting head to r.\r\nRev.: Palm tree, with seven branches and two clusters of dates, around Latin inscription',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Purchase'},
#  {'id': 323640,
#   'title': 'Countermarked As of Nero, Lugdunum',
#   'culture': 'Roman Imperial',
#   'period': 'Roman Imperial period, Early',
#   'century': '1st century CE',
#   'medium': 'Bronze',
#   'dimensions': '8.72g',
#   'description': 'Obv.: Laureate head of Nero l.; around, NERO CLAVD CAESAR AVG GERMANICVS. Countermarked S P Q R across lower half of head.\r\nRev.: Victory flying l., holding in both hands shield inscribed [S P Q R]; to l. and r., S-C.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2008,
#   'accessionmethod': 'Gift'},
#  {'id': 47107,
#   'title': 'One of Eight Irish Coins Minted in 1928: Farthing',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '2.81 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47583,
#   'title': 'One of Eight Irish Coins Minted in 1928: Florin',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '11.4 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47584,
#   'title': 'One of Eight Irish Coins Minted in 1928: Shilling',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '5.68 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47585,
#   'title': 'One of Eight Irish Coins Minted in 1928: Threepence',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '3.08 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47586,
#   'title': 'One of Eight Irish Coins Minted in 1928: Sixpence',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '4.4 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47587,
#   'title': 'One of Eight Irish Coins Minted in 1928: Penny',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '9.51 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 47588,
#   'title': 'One of Eight Irish Coins Minted in 1928: Halfpenny',
#   'culture': 'Irish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Metal',
#   'dimensions': '5.67 g',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Coins',
#   'accessionyear': 1943,
#   'accessionmethod': 'Bequest'},
#  {'id': 48199,
#   'title': 'Tetartemorion',
#   'culture': 'Philisto-Arabian',
#   'period': None,
#   'century': '4th century BCE',
#   'medium': 'Silver',
#   'dimensions': '0.2 g',
#   'description': "Obv.: facing head of Bes, bearded with animal ears.\r\nRev.: lion's head to r.",
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2004,
#   'accessionmethod': 'Gift'},
#  {'id': 48207,
#   'title': 'Coin of Tyre',
#   'culture': 'Greek',
#   'period': 'Classical period',
#   'century': '4th century BCE',
#   'medium': 'Bronze',
#   'dimensions': '0.68 g',
#   'description': "Obverse: Dolphin to l.\r\nReverse: Lion'd head facing; border of dots",
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 1980,
#   'accessionmethod': 'Gift'},
#  {'id': 48272,
#   'title': 'Three-assaria coin of Chios under the Antonines',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '2nd century CE',
#   'medium': 'Bronze',
#   'dimensions': '15.06 g',
#   'description': 'Obv.: Sphinx seated to r., with r. fore-paw raised; in front, a prow. Above: ACCAPIA retrograde; in exergue: TPIA\r\nRev.: Apolloon l. holding patera and Dionysos on r., holding thyrsos and cantharos, both standing facing and clad in himatia; between them, a flaming altar. In lower fields l. and r, XIWN.',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2005,
#   'accessionmethod': 'Gift'},
#  {'id': 48273,
#   'title': 'Coin of Julia Paula, Kaisareia-Germanike',
#   'culture': 'Roman Provincial',
#   'period': 'Roman Imperial period, Middle',
#   'century': '3rd century CE',
#   'medium': 'Bronze',
#   'dimensions': '12.49 g',
#   'description': 'Obv.: Bust of Julia Paula to r.\r\nRev.: Athena standing l. holding Nike facing away from her on outstretched r. hand and spear in l. hand.\r\n',
#   'department': 'Department of Ancient and Byzantine Art & Numismatics',
#   'classification': 'Coins',
#   'accessionyear': 2005,
#   'accessionmethod': 'Gift'},
#  {'id': 49523,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '0.65 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49524,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '0.38 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49525,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '0.52 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49526,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '0.52 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49574,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '3.93 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49575,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '3.66 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49576,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '4.63 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49577,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '4.65 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49578,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '4.48 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  {'id': 49579,
#   'title': 'One of 72 coins',
#   'culture': 'Chinese',
#   'period': None,
#   'century': None,
#   'medium': 'Metal',
#   'dimensions': '3.69 g',
#   'description': None,
#   'department': 'Department of Asian Art',
#   'classification': 'Coins',
#   'accessionyear': 1924,
#   'accessionmethod': 'Purchase'},
#  ...]

# %%
len(metadata)
# Out:
# 2500

# %% [markdown]
# ###*artifact_media record and length*

# %%
#media api record is a list of dictionary
media
# Out:
# [{'objectid': 322691,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132751,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 322692,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132752,
#   'datebegin': 108,
#   'dateend': 109},
#  {'objectid': 322693,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132756,
#   'datebegin': 138,
#   'dateend': 161},
#  {'objectid': 322694,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132757,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132758,
#   'datebegin': 177,
#   'dateend': 192},
#  {'objectid': 322696,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132761,
#   'datebegin': 67,
#   'dateend': 68},
#  {'objectid': 322697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132762,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322698,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132765,
#   'datebegin': 253,
#   'dateend': 260},
#  {'objectid': 322699,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132766,
#   'datebegin': 247,
#   'dateend': 249},
#  {'objectid': 322700,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132767,
#   'datebegin': 69,
#   'dateend': 70},
#  {'objectid': 322701,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132770,
#   'datebegin': 109,
#   'dateend': 110},
#  {'objectid': 322702,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132771,
#   'datebegin': 105,
#   'dateend': 106},
#  {'objectid': 322703,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132772,
#   'datebegin': 107,
#   'dateend': 108},
#  {'objectid': 322704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132773,
#   'datebegin': 99,
#   'dateend': 100},
#  {'objectid': 322705,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132774,
#   'datebegin': 151,
#   'dateend': 152},
#  {'objectid': 322706,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132775,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322707,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132776,
#   'datebegin': 106,
#   'dateend': 107},
#  {'objectid': 322708,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132777,
#   'datebegin': 94,
#   'dateend': 95},
#  {'objectid': 322709,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132778,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132779,
#   'datebegin': 217,
#   'dateend': 218},
#  {'objectid': 322711,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132780,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322712,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132781,
#   'datebegin': 87,
#   'dateend': 88},
#  {'objectid': 322713,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132783,
#   'datebegin': 170,
#   'dateend': 180},
#  {'objectid': 322714,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132784,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322715,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132785,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132786,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322717,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132787,
#   'datebegin': 222,
#   'dateend': 235},
#  {'objectid': 322718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132788,
#   'datebegin': 251,
#   'dateend': 251},
#  {'objectid': 322719,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132789,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322720,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132791,
#   'datebegin': 188,
#   'dateend': 217},
#  {'objectid': 322721,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132792,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132799,
#   'datebegin': 249,
#   'dateend': 251},
#  {'objectid': 322978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132800,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132801,
#   'datebegin': 219,
#   'dateend': 220},
#  {'objectid': 322980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132804,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132805,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322982,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132802,
#   'datebegin': 76,
#   'dateend': 77},
#  {'objectid': 322983,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132806,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 322984,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132808,
#   'datebegin': 131,
#   'dateend': 132},
#  {'objectid': 322985,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132809,
#   'datebegin': 118,
#   'dateend': 119},
#  {'objectid': 322986,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132810,
#   'datebegin': 132,
#   'dateend': 137},
#  {'objectid': 322987,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132811,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322988,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132812,
#   'datebegin': 198,
#   'dateend': 199},
#  {'objectid': 322989,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132813,
#   'datebegin': 206,
#   'dateend': 207},
#  {'objectid': 322990,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132814,
#   'datebegin': 130,
#   'dateend': 131},
#  {'objectid': 322991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132815,
#   'datebegin': 251,
#   'dateend': 253},
#  {'objectid': 322992,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132816,
#   'datebegin': 159,
#   'dateend': 160},
#  {'objectid': 322993,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132817,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322994,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132820,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132821,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132822,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132824,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132825,
#   'datebegin': 240,
#   'dateend': 241},
#  {'objectid': 322999,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132826,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 323000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132827,
#   'datebegin': 65,
#   'dateend': 66},
#  {'objectid': 323001,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132828,
#   'datebegin': 379,
#   'dateend': 395},
#  {'objectid': 323002,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132829,
#   'datebegin': 1042,
#   'dateend': 1055},
#  {'objectid': 323003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132830,
#   'datebegin': 1143,
#   'dateend': 1180},
#  {'objectid': 323212,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132732,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323213,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132733,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323214,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132734,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323215,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132735,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323216,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132736,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323217,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132737,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323218,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132738,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323219,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132739,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323220,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132740,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323221,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132741,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323222,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132742,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323223,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132743,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323224,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132744,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323225,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132745,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323226,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132746,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323227,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132747,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323228,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132759,
#   'datebegin': 54,
#   'dateend': 68},
#  {'objectid': 323229,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132794,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 323230,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132796,
#   'datebegin': 81,
#   'dateend': 96},
#  {'objectid': 323231,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 132797,
#   'datebegin': 91,
#   'dateend': 91},
#  {'objectid': 323640,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132618,
#   'datebegin': 65,
#   'dateend': 65},
#  {'objectid': 47107,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70300,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47583,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70294,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47584,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70295,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47585,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70296,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 70297,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47587,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 70298,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 70299,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 48199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 125380,
#   'datebegin': -355,
#   'dateend': -345},
#  {'objectid': 48207,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 102469,
#   'datebegin': -400,
#   'dateend': -333},
#  {'objectid': 48272,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 125692,
#   'datebegin': 138,
#   'dateend': 192},
#  {'objectid': 48273,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 125690,
#   'datebegin': 219,
#   'dateend': 219},
#  {'objectid': 49523,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52888,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49524,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52889,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49525,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 52890,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49526,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 52891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49574,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49575,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49576,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49578,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 52876,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49579,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52877,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322691,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132751,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 322692,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132752,
#   'datebegin': 108,
#   'dateend': 109},
#  {'objectid': 322693,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132756,
#   'datebegin': 138,
#   'dateend': 161},
#  {'objectid': 322694,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132757,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132758,
#   'datebegin': 177,
#   'dateend': 192},
#  {'objectid': 322696,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132761,
#   'datebegin': 67,
#   'dateend': 68},
#  {'objectid': 322697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132762,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322698,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132765,
#   'datebegin': 253,
#   'dateend': 260},
#  {'objectid': 322699,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132766,
#   'datebegin': 247,
#   'dateend': 249},
#  {'objectid': 322700,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132767,
#   'datebegin': 69,
#   'dateend': 70},
#  {'objectid': 322701,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132770,
#   'datebegin': 109,
#   'dateend': 110},
#  {'objectid': 322702,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132771,
#   'datebegin': 105,
#   'dateend': 106},
#  {'objectid': 322703,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132772,
#   'datebegin': 107,
#   'dateend': 108},
#  {'objectid': 322704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132773,
#   'datebegin': 99,
#   'dateend': 100},
#  {'objectid': 322705,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132774,
#   'datebegin': 151,
#   'dateend': 152},
#  {'objectid': 322706,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132775,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322707,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132776,
#   'datebegin': 106,
#   'dateend': 107},
#  {'objectid': 322708,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132777,
#   'datebegin': 94,
#   'dateend': 95},
#  {'objectid': 322709,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132778,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132779,
#   'datebegin': 217,
#   'dateend': 218},
#  {'objectid': 322711,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132780,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322712,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132781,
#   'datebegin': 87,
#   'dateend': 88},
#  {'objectid': 322713,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132783,
#   'datebegin': 170,
#   'dateend': 180},
#  {'objectid': 322714,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132784,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322715,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132785,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132786,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322717,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132787,
#   'datebegin': 222,
#   'dateend': 235},
#  {'objectid': 322718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132788,
#   'datebegin': 251,
#   'dateend': 251},
#  {'objectid': 322719,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132789,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322720,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132791,
#   'datebegin': 188,
#   'dateend': 217},
#  {'objectid': 322721,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132792,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132799,
#   'datebegin': 249,
#   'dateend': 251},
#  {'objectid': 322978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132800,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132801,
#   'datebegin': 219,
#   'dateend': 220},
#  {'objectid': 322980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132804,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132805,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322982,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132802,
#   'datebegin': 76,
#   'dateend': 77},
#  {'objectid': 322983,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132806,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 322984,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132808,
#   'datebegin': 131,
#   'dateend': 132},
#  {'objectid': 322985,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132809,
#   'datebegin': 118,
#   'dateend': 119},
#  {'objectid': 322986,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132810,
#   'datebegin': 132,
#   'dateend': 137},
#  {'objectid': 322987,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132811,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322988,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132812,
#   'datebegin': 198,
#   'dateend': 199},
#  {'objectid': 322989,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132813,
#   'datebegin': 206,
#   'dateend': 207},
#  {'objectid': 322990,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132814,
#   'datebegin': 130,
#   'dateend': 131},
#  {'objectid': 322991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132815,
#   'datebegin': 251,
#   'dateend': 253},
#  {'objectid': 322992,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132816,
#   'datebegin': 159,
#   'dateend': 160},
#  {'objectid': 322993,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132817,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322994,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132820,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132821,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132822,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132824,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132825,
#   'datebegin': 240,
#   'dateend': 241},
#  {'objectid': 322999,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132826,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 323000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132827,
#   'datebegin': 65,
#   'dateend': 66},
#  {'objectid': 323001,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132828,
#   'datebegin': 379,
#   'dateend': 395},
#  {'objectid': 323002,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132829,
#   'datebegin': 1042,
#   'dateend': 1055},
#  {'objectid': 323003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132830,
#   'datebegin': 1143,
#   'dateend': 1180},
#  {'objectid': 323212,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132732,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323213,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132733,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323214,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132734,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323215,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132735,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323216,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132736,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323217,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132737,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323218,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132738,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323219,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132739,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323220,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132740,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323221,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132741,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323222,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132742,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323223,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132743,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323224,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132744,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323225,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132745,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323226,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132746,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323227,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132747,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323228,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132759,
#   'datebegin': 54,
#   'dateend': 68},
#  {'objectid': 323229,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132794,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 323230,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132796,
#   'datebegin': 81,
#   'dateend': 96},
#  {'objectid': 323231,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 132797,
#   'datebegin': 91,
#   'dateend': 91},
#  {'objectid': 323640,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132618,
#   'datebegin': 65,
#   'dateend': 65},
#  {'objectid': 47107,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70300,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47583,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70294,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47584,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70295,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47585,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70296,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 70297,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47587,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 70298,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 70299,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 48199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 125380,
#   'datebegin': -355,
#   'dateend': -345},
#  {'objectid': 48207,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 102469,
#   'datebegin': -400,
#   'dateend': -333},
#  {'objectid': 48272,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 125692,
#   'datebegin': 138,
#   'dateend': 192},
#  {'objectid': 48273,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 125690,
#   'datebegin': 219,
#   'dateend': 219},
#  {'objectid': 49523,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52888,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49524,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52889,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49525,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 52890,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49526,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 52891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49574,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49575,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49576,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49578,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 52876,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49579,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52877,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322691,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132751,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 322692,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132752,
#   'datebegin': 108,
#   'dateend': 109},
#  {'objectid': 322693,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132756,
#   'datebegin': 138,
#   'dateend': 161},
#  {'objectid': 322694,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132757,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132758,
#   'datebegin': 177,
#   'dateend': 192},
#  {'objectid': 322696,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132761,
#   'datebegin': 67,
#   'dateend': 68},
#  {'objectid': 322697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132762,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322698,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132765,
#   'datebegin': 253,
#   'dateend': 260},
#  {'objectid': 322699,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132766,
#   'datebegin': 247,
#   'dateend': 249},
#  {'objectid': 322700,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132767,
#   'datebegin': 69,
#   'dateend': 70},
#  {'objectid': 322701,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132770,
#   'datebegin': 109,
#   'dateend': 110},
#  {'objectid': 322702,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132771,
#   'datebegin': 105,
#   'dateend': 106},
#  {'objectid': 322703,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132772,
#   'datebegin': 107,
#   'dateend': 108},
#  {'objectid': 322704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132773,
#   'datebegin': 99,
#   'dateend': 100},
#  {'objectid': 322705,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132774,
#   'datebegin': 151,
#   'dateend': 152},
#  {'objectid': 322706,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132775,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322707,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132776,
#   'datebegin': 106,
#   'dateend': 107},
#  {'objectid': 322708,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132777,
#   'datebegin': 94,
#   'dateend': 95},
#  {'objectid': 322709,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132778,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132779,
#   'datebegin': 217,
#   'dateend': 218},
#  {'objectid': 322711,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132780,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322712,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132781,
#   'datebegin': 87,
#   'dateend': 88},
#  {'objectid': 322713,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132783,
#   'datebegin': 170,
#   'dateend': 180},
#  {'objectid': 322714,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132784,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322715,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132785,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132786,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322717,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132787,
#   'datebegin': 222,
#   'dateend': 235},
#  {'objectid': 322718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132788,
#   'datebegin': 251,
#   'dateend': 251},
#  {'objectid': 322719,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132789,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322720,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132791,
#   'datebegin': 188,
#   'dateend': 217},
#  {'objectid': 322721,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132792,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132799,
#   'datebegin': 249,
#   'dateend': 251},
#  {'objectid': 322978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132800,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132801,
#   'datebegin': 219,
#   'dateend': 220},
#  {'objectid': 322980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132804,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132805,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322982,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132802,
#   'datebegin': 76,
#   'dateend': 77},
#  {'objectid': 322983,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132806,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 322984,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132808,
#   'datebegin': 131,
#   'dateend': 132},
#  {'objectid': 322985,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132809,
#   'datebegin': 118,
#   'dateend': 119},
#  {'objectid': 322986,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132810,
#   'datebegin': 132,
#   'dateend': 137},
#  {'objectid': 322987,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132811,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322988,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132812,
#   'datebegin': 198,
#   'dateend': 199},
#  {'objectid': 322989,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132813,
#   'datebegin': 206,
#   'dateend': 207},
#  {'objectid': 322990,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132814,
#   'datebegin': 130,
#   'dateend': 131},
#  {'objectid': 322991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132815,
#   'datebegin': 251,
#   'dateend': 253},
#  {'objectid': 322992,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132816,
#   'datebegin': 159,
#   'dateend': 160},
#  {'objectid': 322993,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132817,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322994,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132820,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132821,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132822,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132824,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132825,
#   'datebegin': 240,
#   'dateend': 241},
#  {'objectid': 322999,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132826,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 323000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132827,
#   'datebegin': 65,
#   'dateend': 66},
#  {'objectid': 323001,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132828,
#   'datebegin': 379,
#   'dateend': 395},
#  {'objectid': 323002,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132829,
#   'datebegin': 1042,
#   'dateend': 1055},
#  {'objectid': 323003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132830,
#   'datebegin': 1143,
#   'dateend': 1180},
#  {'objectid': 323212,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132732,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323213,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132733,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323214,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132734,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323215,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132735,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323216,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132736,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323217,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132737,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323218,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132738,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323219,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132739,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323220,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132740,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323221,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132741,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323222,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132742,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323223,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132743,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323224,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132744,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323225,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132745,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323226,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132746,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323227,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132747,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323228,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132759,
#   'datebegin': 54,
#   'dateend': 68},
#  {'objectid': 323229,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132794,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 323230,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132796,
#   'datebegin': 81,
#   'dateend': 96},
#  {'objectid': 323231,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 132797,
#   'datebegin': 91,
#   'dateend': 91},
#  {'objectid': 323640,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132618,
#   'datebegin': 65,
#   'dateend': 65},
#  {'objectid': 47107,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70300,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47583,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70294,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47584,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70295,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47585,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70296,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 70297,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47587,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 70298,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 70299,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 48199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 125380,
#   'datebegin': -355,
#   'dateend': -345},
#  {'objectid': 48207,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 102469,
#   'datebegin': -400,
#   'dateend': -333},
#  {'objectid': 48272,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 125692,
#   'datebegin': 138,
#   'dateend': 192},
#  {'objectid': 48273,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 125690,
#   'datebegin': 219,
#   'dateend': 219},
#  {'objectid': 49523,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52888,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49524,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52889,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49525,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 52890,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49526,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 52891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49574,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49575,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49576,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49578,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 52876,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49579,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52877,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322691,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132751,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 322692,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132752,
#   'datebegin': 108,
#   'dateend': 109},
#  {'objectid': 322693,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132756,
#   'datebegin': 138,
#   'dateend': 161},
#  {'objectid': 322694,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132757,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132758,
#   'datebegin': 177,
#   'dateend': 192},
#  {'objectid': 322696,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132761,
#   'datebegin': 67,
#   'dateend': 68},
#  {'objectid': 322697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132762,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322698,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132765,
#   'datebegin': 253,
#   'dateend': 260},
#  {'objectid': 322699,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132766,
#   'datebegin': 247,
#   'dateend': 249},
#  {'objectid': 322700,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132767,
#   'datebegin': 69,
#   'dateend': 70},
#  {'objectid': 322701,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132770,
#   'datebegin': 109,
#   'dateend': 110},
#  {'objectid': 322702,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132771,
#   'datebegin': 105,
#   'dateend': 106},
#  {'objectid': 322703,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132772,
#   'datebegin': 107,
#   'dateend': 108},
#  {'objectid': 322704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132773,
#   'datebegin': 99,
#   'dateend': 100},
#  {'objectid': 322705,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132774,
#   'datebegin': 151,
#   'dateend': 152},
#  {'objectid': 322706,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132775,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322707,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132776,
#   'datebegin': 106,
#   'dateend': 107},
#  {'objectid': 322708,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132777,
#   'datebegin': 94,
#   'dateend': 95},
#  {'objectid': 322709,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132778,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132779,
#   'datebegin': 217,
#   'dateend': 218},
#  {'objectid': 322711,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132780,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322712,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132781,
#   'datebegin': 87,
#   'dateend': 88},
#  {'objectid': 322713,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132783,
#   'datebegin': 170,
#   'dateend': 180},
#  {'objectid': 322714,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132784,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322715,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132785,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132786,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322717,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132787,
#   'datebegin': 222,
#   'dateend': 235},
#  {'objectid': 322718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132788,
#   'datebegin': 251,
#   'dateend': 251},
#  {'objectid': 322719,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132789,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322720,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132791,
#   'datebegin': 188,
#   'dateend': 217},
#  {'objectid': 322721,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132792,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132799,
#   'datebegin': 249,
#   'dateend': 251},
#  {'objectid': 322978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132800,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132801,
#   'datebegin': 219,
#   'dateend': 220},
#  {'objectid': 322980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132804,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132805,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322982,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132802,
#   'datebegin': 76,
#   'dateend': 77},
#  {'objectid': 322983,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132806,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 322984,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132808,
#   'datebegin': 131,
#   'dateend': 132},
#  {'objectid': 322985,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132809,
#   'datebegin': 118,
#   'dateend': 119},
#  {'objectid': 322986,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132810,
#   'datebegin': 132,
#   'dateend': 137},
#  {'objectid': 322987,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132811,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322988,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132812,
#   'datebegin': 198,
#   'dateend': 199},
#  {'objectid': 322989,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132813,
#   'datebegin': 206,
#   'dateend': 207},
#  {'objectid': 322990,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132814,
#   'datebegin': 130,
#   'dateend': 131},
#  {'objectid': 322991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132815,
#   'datebegin': 251,
#   'dateend': 253},
#  {'objectid': 322992,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132816,
#   'datebegin': 159,
#   'dateend': 160},
#  {'objectid': 322993,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132817,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322994,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132820,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132821,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132822,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132824,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132825,
#   'datebegin': 240,
#   'dateend': 241},
#  {'objectid': 322999,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132826,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 323000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132827,
#   'datebegin': 65,
#   'dateend': 66},
#  {'objectid': 323001,
# ...
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70295,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47585,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70296,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 70297,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47587,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 70298,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 70299,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 48199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 125380,
#   'datebegin': -355,
#   'dateend': -345},
#  {'objectid': 48207,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 102469,
#   'datebegin': -400,
#   'dateend': -333},
#  {'objectid': 48272,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 125692,
#   'datebegin': 138,
#   'dateend': 192},
#  {'objectid': 48273,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 125690,
#   'datebegin': 219,
#   'dateend': 219},
#  {'objectid': 49523,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52888,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49524,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52889,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49525,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 52890,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49526,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 52891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49574,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49575,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49576,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49578,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 52876,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49579,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52877,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322691,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132751,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 322692,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132752,
#   'datebegin': 108,
#   'dateend': 109},
#  {'objectid': 322693,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132756,
#   'datebegin': 138,
#   'dateend': 161},
#  {'objectid': 322694,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132757,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132758,
#   'datebegin': 177,
#   'dateend': 192},
#  {'objectid': 322696,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132761,
#   'datebegin': 67,
#   'dateend': 68},
#  {'objectid': 322697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132762,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322698,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132765,
#   'datebegin': 253,
#   'dateend': 260},
#  {'objectid': 322699,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132766,
#   'datebegin': 247,
#   'dateend': 249},
#  {'objectid': 322700,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132767,
#   'datebegin': 69,
#   'dateend': 70},
#  {'objectid': 322701,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132770,
#   'datebegin': 109,
#   'dateend': 110},
#  {'objectid': 322702,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132771,
#   'datebegin': 105,
#   'dateend': 106},
#  {'objectid': 322703,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132772,
#   'datebegin': 107,
#   'dateend': 108},
#  {'objectid': 322704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132773,
#   'datebegin': 99,
#   'dateend': 100},
#  {'objectid': 322705,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132774,
#   'datebegin': 151,
#   'dateend': 152},
#  {'objectid': 322706,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132775,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322707,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132776,
#   'datebegin': 106,
#   'dateend': 107},
#  {'objectid': 322708,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132777,
#   'datebegin': 94,
#   'dateend': 95},
#  {'objectid': 322709,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank': 132778,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132779,
#   'datebegin': 217,
#   'dateend': 218},
#  {'objectid': 322711,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132780,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322712,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132781,
#   'datebegin': 87,
#   'dateend': 88},
#  {'objectid': 322713,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132783,
#   'datebegin': 170,
#   'dateend': 180},
#  {'objectid': 322714,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132784,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322715,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132785,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132786,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322717,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132787,
#   'datebegin': 222,
#   'dateend': 235},
#  {'objectid': 322718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132788,
#   'datebegin': 251,
#   'dateend': 251},
#  {'objectid': 322719,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132789,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322720,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132791,
#   'datebegin': 188,
#   'dateend': 217},
#  {'objectid': 322721,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132792,
#   'datebegin': 117,
#   'dateend': 138},
#  {'objectid': 322976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132799,
#   'datebegin': 249,
#   'dateend': 251},
#  {'objectid': 322978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132800,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 322979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132801,
#   'datebegin': 219,
#   'dateend': 220},
#  {'objectid': 322980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132804,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132805,
#   'datebegin': -40,
#   'dateend': -39},
#  {'objectid': 322982,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132802,
#   'datebegin': 76,
#   'dateend': 77},
#  {'objectid': 322983,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132806,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 322984,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132808,
#   'datebegin': 131,
#   'dateend': 132},
#  {'objectid': 322985,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132809,
#   'datebegin': 118,
#   'dateend': 119},
#  {'objectid': 322986,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132810,
#   'datebegin': 132,
#   'dateend': 137},
#  {'objectid': 322987,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132811,
#   'datebegin': 150,
#   'dateend': 151},
#  {'objectid': 322988,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132812,
#   'datebegin': 198,
#   'dateend': 199},
#  {'objectid': 322989,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132813,
#   'datebegin': 206,
#   'dateend': 207},
#  {'objectid': 322990,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132814,
#   'datebegin': 130,
#   'dateend': 131},
#  {'objectid': 322991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132815,
#   'datebegin': 251,
#   'dateend': 253},
#  {'objectid': 322992,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132816,
#   'datebegin': 159,
#   'dateend': 160},
#  {'objectid': 322993,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132817,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322994,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132820,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132821,
#   'datebegin': 218,
#   'dateend': 222},
#  {'objectid': 322996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132822,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132824,
#   'datebegin': 244,
#   'dateend': 249},
#  {'objectid': 322998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132825,
#   'datebegin': 240,
#   'dateend': 241},
#  {'objectid': 322999,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132826,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 323000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132827,
#   'datebegin': 65,
#   'dateend': 66},
#  {'objectid': 323001,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132828,
#   'datebegin': 379,
#   'dateend': 395},
#  {'objectid': 323002,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132829,
#   'datebegin': 1042,
#   'dateend': 1055},
#  {'objectid': 323003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132830,
#   'datebegin': 1143,
#   'dateend': 1180},
#  {'objectid': 323212,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132732,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323213,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132733,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323214,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132734,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323215,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132735,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323216,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132736,
#   'datebegin': 133,
#   'dateend': 134},
#  {'objectid': 323217,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 132737,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323218,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132738,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323219,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132739,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323220,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132740,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323221,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 132741,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323222,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132742,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323223,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 132743,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323224,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132744,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323225,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132745,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323226,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 132746,
#   'datebegin': 132,
#   'dateend': 135},
#  {'objectid': 323227,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132747,
#   'datebegin': 132,
#   'dateend': 133},
#  {'objectid': 323228,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132759,
#   'datebegin': 54,
#   'dateend': 68},
#  {'objectid': 323229,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 132794,
#   'datebegin': 98,
#   'dateend': 117},
#  {'objectid': 323230,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132796,
#   'datebegin': 81,
#   'dateend': 96},
#  {'objectid': 323231,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 132797,
#   'datebegin': 91,
#   'dateend': 91},
#  {'objectid': 323640,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 132618,
#   'datebegin': 65,
#   'dateend': 65},
#  {'objectid': 47107,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70300,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47583,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank': 70294,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47584,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70295,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47585,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 70296,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 70297,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47587,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 70298,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 47588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 70299,
#   'datebegin': 1928,
#   'dateend': 1928},
#  {'objectid': 48199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 125380,
#   'datebegin': -355,
#   'dateend': -345},
#  {'objectid': 48207,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 2,
#   'rank': 102469,
#   'datebegin': -400,
#   'dateend': -333},
#  {'objectid': 48272,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 125692,
#   'datebegin': 138,
#   'dateend': 192},
#  {'objectid': 48273,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 125690,
#   'datebegin': 219,
#   'dateend': 219},
#  {'objectid': 49523,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52888,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49524,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52889,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49525,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank': 52890,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49526,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank': 52891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49574,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49575,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49576,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank': 52870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank': 52871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49578,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank': 52876,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 49579,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank': 52877,
#   'datebegin': 0,
#   'dateend': 0},
#  ...]

# %%
len(media)
# Out:
# 2500

# %% [markdown]
# ###*artifact_colors record and length*

# %%
#colors api record is a list of dictionary
colors
# Out:
# [{'objectid': 322691,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7857971014492754,
#   'css3': '#000000'},
#  {'objectid': 322691,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.19845410628019325,
#   'css3': '#556b2f'},
#  {'objectid': 322691,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.013623188405797102,
#   'css3': '#696969'},
#  {'objectid': 322691,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.0021256038647342996,
#   'css3': '#808080'},
#  {'objectid': 322692,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.796231884057971,
#   'css3': '#000000'},
#  {'objectid': 322692,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.08270531400966183,
#   'css3': '#2f4f4f'},
#  {'objectid': 322692,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.05545893719806763,
#   'css3': '#556b2f'},
#  {'objectid': 322692,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.03874396135265701,
#   'css3': '#556b2f'},
#  {'objectid': 322692,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.017198067632850242,
#   'css3': '#a0522d'},
#  {'objectid': 322692,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 0.00966183574879227,
#   'css3': '#cd853f'},
#  {'objectid': 322693,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.608792270531401,
#   'css3': '#000000'},
#  {'objectid': 322693,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.2217391304347826,
#   'css3': '#556b2f'},
#  {'objectid': 322693,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.08338164251207729,
#   'css3': '#a0522d'},
#  {'objectid': 322693,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.0647342995169082,
#   'css3': '#2f4f4f'},
#  {'objectid': 322693,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.021256038647342997,
#   'css3': '#a0522d'},
#  {'objectid': 322693,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 9.66183574879227e-05,
#   'css3': '#d2b48c'},
#  {'objectid': 322694,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7002898550724638,
#   'css3': '#000000'},
#  {'objectid': 322694,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.13420289855072465,
#   'css3': '#556b2f'},
#  {'objectid': 322694,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.08222222222222222,
#   'css3': '#556b2f'},
#  {'objectid': 322694,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.07169082125603865,
#   'css3': '#2f4f4f'},
#  {'objectid': 322694,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.011594202898550725,
#   'css3': '#a0522d'},
#  {'objectid': 322695,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6223188405797101,
#   'css3': '#000000'},
#  {'objectid': 322695,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.197487922705314,
#   'css3': '#556b2f'},
#  {'objectid': 322695,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.10405797101449275,
#   'css3': '#556b2f'},
#  {'objectid': 322695,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.06115942028985507,
#   'css3': '#696969'},
#  {'objectid': 322695,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.014879227053140097,
#   'css3': '#2f4f4f'},
#  {'objectid': 322695,
#   'color': '#4b9664',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#2e8b57'},
#  {'objectid': 322696,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6870531400966183,
#   'css3': '#000000'},
#  {'objectid': 322696,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.11652173913043479,
#   'css3': '#696969'},
#  {'objectid': 322696,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.10144927536231885,
#   'css3': '#696969'},
#  {'objectid': 322696,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.04743961352657005,
#   'css3': '#556b2f'},
#  {'objectid': 322696,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.02570048309178744,
#   'css3': '#808080'},
#  {'objectid': 322696,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.021835748792270532,
#   'css3': '#2f4f4f'},
#  {'objectid': 322697,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.4910144927536232,
#   'css3': '#000000'},
#  {'objectid': 322697,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.12280193236714976,
#   'css3': '#696969'},
#  {'objectid': 322697,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11429951690821256,
#   'css3': '#556b2f'},
#  {'objectid': 322697,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.09777777777777778,
#   'css3': '#808080'},
#  {'objectid': 322697,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.09285024154589372,
#   'css3': '#2f4f4f'},
#  {'objectid': 322697,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.081256038647343,
#   'css3': '#808080'},
#  {'objectid': 322698,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5264734299516908,
#   'css3': '#000000'},
#  {'objectid': 322698,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.21458937198067632,
#   'css3': '#696969'},
#  {'objectid': 322698,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.11246376811594203,
#   'css3': '#696969'},
#  {'objectid': 322698,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.06570048309178744,
#   'css3': '#2f4f4f'},
#  {'objectid': 322698,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.06231884057971015,
#   'css3': '#808080'},
#  {'objectid': 322698,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.014782608695652174,
#   'css3': '#d2b48c'},
#  {'objectid': 322698,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.003671497584541063,
#   'css3': '#000000'},
#  {'objectid': 322699,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5031884057971014,
#   'css3': '#000000'},
#  {'objectid': 322699,
#   'color': '#4b4b19',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.17526570048309179,
#   'css3': '#556b2f'},
#  {'objectid': 322699,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.13256038647342996,
#   'css3': '#a0522d'},
#  {'objectid': 322699,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.12367149758454106,
#   'css3': '#2f4f4f'},
#  {'objectid': 322699,
#   'color': '#af7d32',
#   'spectrum': '#f17c4f',
#   'hue': 'Yellow',
#   'percent': 0.06280193236714976,
#   'css3': '#cd853f'},
#  {'objectid': 322699,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.001932367149758454,
#   'css3': '#cd853f'},
#  {'objectid': 322699,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.0005797101449275362,
#   'css3': '#808080'},
#  {'objectid': 322700,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6633816425120773,
#   'css3': '#000000'},
#  {'objectid': 322700,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.15845410628019324,
#   'css3': '#2f4f4f'},
#  {'objectid': 322700,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.08695652173913043,
#   'css3': '#556b2f'},
#  {'objectid': 322700,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.0485024154589372,
#   'css3': '#8b4513'},
#  {'objectid': 322700,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.03816425120772947,
#   'css3': '#a0522d'},
#  {'objectid': 322700,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.004541062801932367,
#   'css3': '#a0522d'},
#  {'objectid': 322701,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6545893719806763,
#   'css3': '#000000'},
#  {'objectid': 322701,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.09951690821256039,
#   'css3': '#2f4f4f'},
#  {'objectid': 322701,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.078743961352657,
#   'css3': '#556b2f'},
#  {'objectid': 322701,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.07797101449275362,
#   'css3': '#556b2f'},
#  {'objectid': 322701,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.05961352657004831,
#   'css3': '#696969'},
#  {'objectid': 322701,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.029565217391304348,
#   'css3': '#a0522d'},
#  {'objectid': 322702,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7481159420289855,
#   'css3': '#000000'},
#  {'objectid': 322702,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.10705314009661836,
#   'css3': '#556b2f'},
#  {'objectid': 322702,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.06541062801932367,
#   'css3': '#2f4f4f'},
#  {'objectid': 322702,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.04067632850241546,
#   'css3': '#696969'},
#  {'objectid': 322702,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0323671497584541,
#   'css3': '#a0522d'},
#  {'objectid': 322702,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.006280193236714976,
#   'css3': '#bdb76b'},
#  {'objectid': 322702,
#   'color': '#c8967d',
#   'spectrum': '#e66c64',
#   'hue': 'Grey',
#   'percent': 9.66183574879227e-05,
#   'css3': '#bc8f8f'},
#  {'objectid': 322703,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.673719806763285,
#   'css3': '#000000'},
#  {'objectid': 322703,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.14454106280193238,
#   'css3': '#556b2f'},
#  {'objectid': 322703,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.13623188405797101,
#   'css3': '#2f4f4f'},
#  {'objectid': 322703,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.04396135265700483,
#   'css3': '#696969'},
#  {'objectid': 322703,
#   'color': '#4b7d64',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.0014492753623188406,
#   'css3': '#2e8b57'},
#  {'objectid': 322703,
#   'color': '#4b967d',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#3cb371'},
#  {'objectid': 322704,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5445410628019324,
#   'css3': '#000000'},
#  {'objectid': 322704,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.1902415458937198,
#   'css3': '#556b2f'},
#  {'objectid': 322704,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.18280193236714976,
#   'css3': '#2f4f4f'},
#  {'objectid': 322704,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.08231884057971015,
#   'css3': '#556b2f'},
#  {'objectid': 322704,
#   'color': '#afaf7d',
#   'spectrum': '#9ecb3b',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#bdb76b'},
#  {'objectid': 322705,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7235748792270531,
#   'css3': '#000000'},
#  {'objectid': 322705,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.08579710144927537,
#   'css3': '#808080'},
#  {'objectid': 322705,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.07352657004830918,
#   'css3': '#696969'},
#  {'objectid': 322705,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.05381642512077295,
#   'css3': '#556b2f'},
#  {'objectid': 322705,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.03111111111111111,
#   'css3': '#808080'},
#  {'objectid': 322705,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.02705314009661836,
#   'css3': '#2f4f4f'},
#  {'objectid': 322705,
#   'color': '#96af96',
#   'spectrum': '#8163ab',
#   'hue': 'Green',
#   'percent': 0.005120772946859903,
#   'css3': '#8fbc8f'},
#  {'objectid': 322707,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5566183574879227,
#   'css3': '#000000'},
#  {'objectid': 322707,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.1373913043478261,
#   'css3': '#696969'},
#  {'objectid': 322707,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.13478260869565217,
#   'css3': '#696969'},
#  {'objectid': 322707,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.08115942028985507,
#   'css3': '#556b2f'},
#  {'objectid': 322707,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.04676328502415459,
#   'css3': '#2f4f4f'},
#  {'objectid': 322707,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.043285024154589374,
#   'css3': '#808080'},
#  {'objectid': 322708,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7791304347826087,
#   'css3': '#000000'},
#  {'objectid': 322708,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.15768115942028985,
#   'css3': '#2f4f4f'},
#  {'objectid': 322708,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.06318840579710144,
#   'css3': '#556b2f'},
#  {'objectid': 322710,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5434782608695652,
#   'css3': '#000000'},
#  {'objectid': 322710,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.42570048309178743,
#   'css3': '#2f4f4f'},
#  {'objectid': 322710,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.030821256038647344,
#   'css3': '#556b2f'},
#  {'objectid': 322711,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8593236714975846,
#   'css3': '#000000'},
#  {'objectid': 322711,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.08454106280193237,
#   'css3': '#2f4f4f'},
#  {'objectid': 322711,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.04772946859903382,
#   'css3': '#8b4513'},
#  {'objectid': 322711,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.008405797101449276,
#   'css3': '#a0522d'},
#  {'objectid': 322712,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6421256038647343,
#   'css3': '#000000'},
#  {'objectid': 322712,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.19594202898550725,
#   'css3': '#556b2f'},
#  {'objectid': 322712,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.10628019323671498,
#   'css3': '#696969'},
#  {'objectid': 322712,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.042705314009661835,
#   'css3': '#808080'},
#  {'objectid': 322712,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.012946859903381642,
#   'css3': '#808080'},
#  {'objectid': 322713,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.537584541062802,
#   'css3': '#000000'},
#  {'objectid': 322713,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.20502415458937198,
#   'css3': '#556b2f'},
#  {'objectid': 322713,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.15729468599033816,
#   'css3': '#a0522d'},
#  {'objectid': 322713,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.05236714975845411,
#   'css3': '#2f4f4f'},
#  {'objectid': 322713,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.04705314009661836,
#   'css3': '#cd853f'},
#  {'objectid': 322713,
#   'color': '#19644b',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 0.0003864734299516908,
#   'css3': '#2f4f4f'},
#  {'objectid': 322713,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.0002898550724637681,
#   'css3': '#bdb76b'},
#  {'objectid': 322714,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5925603864734299,
#   'css3': '#000000'},
#  {'objectid': 322714,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.19304347826086957,
#   'css3': '#2f4f4f'},
#  {'objectid': 322714,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.12966183574879228,
#   'css3': '#2f4f4f'},
#  {'objectid': 322714,
#   'color': '#4b644b',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.08019323671497584,
#   'css3': '#556b2f'},
#  {'objectid': 322714,
#   'color': '#af7d32',
#   'spectrum': '#f17c4f',
#   'hue': 'Yellow',
#   'percent': 0.0022222222222222222,
#   'css3': '#cd853f'},
#  {'objectid': 322714,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.001256038647342995,
#   'css3': '#a0522d'},
#  {'objectid': 322714,
#   'color': '#64967d',
#   'spectrum': '#47b853',
#   'hue': 'Green',
#   'percent': 0.0005797101449275362,
#   'css3': '#708090'},
#  {'objectid': 322714,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.0004830917874396135,
#   'css3': '#cd853f'},
#  {'objectid': 322715,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.49120772946859903,
#   'css3': '#000000'},
#  {'objectid': 322715,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.15429951690821256,
#   'css3': '#2f4f4f'},
#  {'objectid': 322715,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.10898550724637682,
#   'css3': '#556b2f'},
#  {'objectid': 322715,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.09719806763285024,
#   'css3': '#a0522d'},
#  {'objectid': 322715,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.078743961352657,
#   'css3': '#556b2f'},
#  {'objectid': 322715,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.04357487922705314,
#   'css3': '#696969'},
#  {'objectid': 322715,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.025990338164251208,
#   'css3': '#bdb76b'},
#  {'objectid': 322716,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7180676328502416,
#   'css3': '#000000'},
#  {'objectid': 322716,
#   'color': '#4b4b19',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.13468599033816425,
#   'css3': '#556b2f'},
#  {'objectid': 322716,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.12067632850241546,
#   'css3': '#2f4f4f'},
#  {'objectid': 322716,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.026570048309178744,
#   'css3': '#a0522d'},
#  {'objectid': 322717,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7153623188405797,
#   'css3': '#000000'},
#  {'objectid': 322717,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.12608695652173912,
#   'css3': '#2f4f4f'},
#  {'objectid': 322717,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.09806763285024155,
#   'css3': '#556b2f'},
#  {'objectid': 322717,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.048792270531400964,
#   'css3': '#556b2f'},
#  {'objectid': 322717,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.010724637681159421,
#   'css3': '#a0522d'},
#  {'objectid': 322717,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.000676328502415459,
#   'css3': '#808080'},
#  {'objectid': 322717,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 0.0002898550724637681,
#   'css3': '#cd853f'},
#  {'objectid': 322718,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5488888888888889,
#   'css3': '#000000'},
#  {'objectid': 322718,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.18618357487922704,
#   'css3': '#2f4f4f'},
#  {'objectid': 322718,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.18521739130434783,
#   'css3': '#556b2f'},
#  {'objectid': 322718,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.06753623188405797,
#   'css3': '#a0522d'},
#  {'objectid': 322718,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.01217391304347826,
#   'css3': '#a0522d'},
#  {'objectid': 322719,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7094685990338164,
#   'css3': '#000000'},
#  {'objectid': 322719,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11806763285024155,
#   'css3': '#556b2f'},
#  {'objectid': 322719,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.08183574879227053,
#   'css3': '#556b2f'},
#  {'objectid': 322719,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.049855072463768114,
#   'css3': '#2f4f4f'},
#  {'objectid': 322719,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.04077294685990338,
#   'css3': '#696969'},
#  {'objectid': 322720,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8800966183574879,
#   'css3': '#000000'},
#  {'objectid': 322720,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11874396135265701,
#   'css3': '#556b2f'},
#  {'objectid': 322720,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0011594202898550724,
#   'css3': '#a0522d'},
#  {'objectid': 322721,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6529468599033816,
#   'css3': '#000000'},
#  {'objectid': 322721,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.2353623188405797,
#   'css3': '#2f4f4f'},
#  {'objectid': 322721,
#   'color': '#193232',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 0.10338164251207729,
#   'css3': '#2f4f4f'},
#  {'objectid': 322721,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.008309178743961353,
#   'css3': '#000000'},
#  {'objectid': 322976,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6396135265700483,
#   'css3': '#000000'},
#  {'objectid': 322976,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11758454106280193,
#   'css3': '#696969'},
#  {'objectid': 322976,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.08714975845410627,
#   'css3': '#696969'},
#  {'objectid': 322976,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.05285024154589372,
#   'css3': '#808080'},
#  {'objectid': 322976,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.05236714975845411,
#   'css3': '#556b2f'},
#  {'objectid': 322976,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.036618357487922706,
#   'css3': '#bdb76b'},
#  {'objectid': 322976,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.012270531400966183,
#   'css3': '#2f4f4f'},
#  {'objectid': 322976,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.0015458937198067632,
#   'css3': '#d2b48c'},
#  {'objectid': 322978,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7543961352657005,
#   'css3': '#000000'},
#  {'objectid': 322978,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.1655072463768116,
#   'css3': '#556b2f'},
#  {'objectid': 322978,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.05236714975845411,
#   'css3': '#a0522d'},
#  {'objectid': 322978,
#   'color': '#967d32',
#   'spectrum': '#86c440',
#   'hue': 'Yellow',
#   'percent': 0.02289855072463768,
#   'css3': '#a0522d'},
#  {'objectid': 322978,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0037681159420289855,
#   'css3': '#000000'},
#  {'objectid': 322978,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.0010628019323671498,
#   'css3': '#cd853f'},
#  {'objectid': 322979,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6753623188405797,
#   'css3': '#000000'},
#  {'objectid': 322979,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.1413526570048309,
#   'css3': '#808080'},
#  {'objectid': 322979,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11932367149758454,
#   'css3': '#696969'},
#  {'objectid': 322979,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.050628019323671496,
#   'css3': '#556b2f'},
#  {'objectid': 322979,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.013333333333333334,
#   'css3': '#2f4f4f'},
#  {'objectid': 322980,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7275362318840579,
#   'css3': '#000000'},
#  {'objectid': 322980,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11265700483091788,
#   'css3': '#696969'},
#  {'objectid': 322980,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.08367149758454107,
#   'css3': '#556b2f'},
#  {'objectid': 322980,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.059033816425120775,
#   'css3': '#808080'},
#  {'objectid': 322980,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.017101449275362317,
#   'css3': '#808080'},
#  {'objectid': 322981,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7964251207729469,
#   'css3': '#000000'},
#  {'objectid': 322981,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.10492753623188406,
#   'css3': '#a0522d'},
#  {'objectid': 322981,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.0548792270531401,
#   'css3': '#696969'},
#  {'objectid': 322981,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.043768115942028986,
#   'css3': '#556b2f'},
#  {'objectid': 322982,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6942995169082126,
#   'css3': '#000000'},
#  {'objectid': 322982,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.1608695652173913,
#   'css3': '#556b2f'},
#  {'objectid': 322982,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.12415458937198068,
#   'css3': '#556b2f'},
#  {'objectid': 322982,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.020676328502415457,
#   'css3': '#2f4f4f'},
#  {'objectid': 322983,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6460869565217391,
#   'css3': '#000000'},
#  {'objectid': 322983,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.31758454106280193,
#   'css3': '#556b2f'},
#  {'objectid': 322983,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.035265700483091786,
#   'css3': '#556b2f'},
#  {'objectid': 322983,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.0010628019323671498,
#   'css3': '#696969'},
#  {'objectid': 322984,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7481159420289855,
#   'css3': '#000000'},
#  {'objectid': 322984,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11884057971014493,
#   'css3': '#696969'},
#  {'objectid': 322984,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.06038647342995169,
#   'css3': '#a0522d'},
#  {'objectid': 322984,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.04811594202898551,
#   'css3': '#556b2f'},
#  {'objectid': 322984,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.02280193236714976,
#   'css3': '#2f4f4f'},
#  {'objectid': 322984,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.0017391304347826088,
#   'css3': '#bdb76b'},
#  {'objectid': 322985,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6541062801932367,
#   'css3': '#000000'},
#  {'objectid': 322985,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.13468599033816425,
#   'css3': '#2f4f4f'},
#  {'objectid': 322985,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.10628019323671498,
#   'css3': '#556b2f'},
#  {'objectid': 322985,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.09178743961352658,
#   'css3': '#a0522d'},
#  {'objectid': 322985,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.008985507246376812,
#   'css3': '#cd853f'},
#  {'objectid': 322985,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.0034782608695652175,
#   'css3': '#cd853f'},
#  {'objectid': 322985,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.0003864734299516908,
#   'css3': '#d2b48c'},
#  {'objectid': 322985,
#   'color': '#e1af64',
#   'spectrum': '#f6903d',
#   'hue': 'Yellow',
#   'percent': 0.0002898550724637681,
#   'css3': '#f4a460'},
#  {'objectid': 322986,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6467632850241546,
#   'css3': '#000000'},
#  {'objectid': 322986,
#   'color': '#4b9696',
#   'spectrum': '#4a70b7',
#   'hue': 'Blue',
#   'percent': 0.12415458937198068,
#   'css3': '#5f9ea0'},
#  {'objectid': 322986,
#   'color': '#64afaf',
#   'spectrum': '#5b6eb4',
#   'hue': 'Blue',
#   'percent': 0.10618357487922706,
#   'css3': '#5f9ea0'},
#  {'objectid': 322986,
#   'color': '#4b7d64',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.06405797101449276,
#   'css3': '#2e8b57'},
#  {'objectid': 322986,
#   'color': '#4b644b',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.029468599033816423,
#   'css3': '#556b2f'},
#  {'objectid': 322986,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.019130434782608695,
#   'css3': '#2f4f4f'},
#  {'objectid': 322986,
#   'color': '#193232',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 0.010241545893719806,
#   'css3': '#2f4f4f'},
#  {'objectid': 322987,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.9029951690821256,
#   'css3': '#000000'},
#  {'objectid': 322987,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.050531400966183575,
#   'css3': '#696969'},
#  {'objectid': 322987,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.0336231884057971,
#   'css3': '#696969'},
#  {'objectid': 322987,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.007342995169082126,
#   'css3': '#808080'},
#  {'objectid': 322987,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0055072463768115944,
#   'css3': '#000000'},
#  {'objectid': 322988,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6030917874396136,
#   'css3': '#000000'},
#  {'objectid': 322988,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.16115942028985508,
#   'css3': '#696969'},
#  {'objectid': 322988,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.14028985507246378,
#   'css3': '#556b2f'},
#  {'objectid': 322988,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.06995169082125603,
#   'css3': '#696969'},
#  {'objectid': 322988,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.025507246376811593,
#   'css3': '#2f4f4f'},
#  {'objectid': 322989,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6601932367149759,
#   'css3': '#000000'},
#  {'objectid': 322989,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.11777777777777777,
#   'css3': '#696969'},
#  {'objectid': 322989,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11516908212560387,
#   'css3': '#556b2f'},
#  {'objectid': 322989,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.07835748792270532,
#   'css3': '#808080'},
#  {'objectid': 322989,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.028502415458937197,
#   'css3': '#808080'},
#  {'objectid': 322990,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8157487922705314,
#   'css3': '#000000'},
#  {'objectid': 322990,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.05468599033816425,
#   'css3': '#696969'},
#  {'objectid': 322990,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.05140096618357488,
#   'css3': '#556b2f'},
#  {'objectid': 322990,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.036231884057971016,
#   'css3': '#696969'},
#  {'objectid': 322990,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.021642512077294687,
#   'css3': '#2f4f4f'},
#  {'objectid': 322990,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.020289855072463767,
#   'css3': '#808080'},
#  {'objectid': 322991,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5740096618357488,
#   'css3': '#000000'},
#  {'objectid': 322991,
#   'color': '#4b644b',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.15188405797101448,
#   'css3': '#556b2f'},
#  {'objectid': 322991,
#   'color': '#647d64',
#   'spectrum': '#4fb94f',
#   'hue': 'Green',
#   'percent': 0.13526570048309178,
#   'css3': '#696969'},
#  {'objectid': 322991,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.08888888888888889,
#   'css3': '#2f4f4f'},
#  {'objectid': 322991,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.042608695652173914,
#   'css3': '#808080'},
#  {'objectid': 322991,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.0055072463768115944,
#   'css3': '#a9a9a9'},
#  {'objectid': 322991,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.001256038647342995,
#   'css3': '#000000'},
#  {'objectid': 322991,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.0005797101449275362,
#   'css3': '#c0c0c0'},
#  {'objectid': 322992,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7401932367149758,
#   'css3': '#000000'},
#  {'objectid': 322992,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.1277294685990338,
#   'css3': '#556b2f'},
#  {'objectid': 322992,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.1132367149758454,
#   'css3': '#2f4f4f'},
#  {'objectid': 322992,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.01855072463768116,
#   'css3': '#a0522d'},
#  {'objectid': 322992,
#   'color': '#643200',
#   'spectrum': '#64bc46',
#   'hue': 'Brown',
#   'percent': 0.0002898550724637681,
#   'css3': '#8b4513'},
#  {'objectid': 322993,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6334299516908213,
#   'css3': '#000000'},
#  {'objectid': 322993,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.20270531400966182,
#   'css3': '#696969'},
#  {'objectid': 322993,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11082125603864734,
#   'css3': '#556b2f'},
#  {'objectid': 322993,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.034106280193236714,
#   'css3': '#696969'},
#  {'objectid': 322993,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.018454106280193238,
#   'css3': '#2f4f4f'},
#  {'objectid': 322993,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.0004830917874396135,
#   'css3': '#bdb76b'},
#  {'objectid': 322994,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.5981720430107527,
#   'css3': '#a9a9a9'},
#  {'objectid': 322994,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.14268817204301076,
#   'css3': '#696969'},
#  {'objectid': 322994,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.12161290322580645,
#   'css3': '#556b2f'},
#  {'objectid': 322994,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.1210752688172043,
#   'css3': '#808080'},
#  {'objectid': 322994,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.015698924731182794,
#   'css3': '#a9a9a9'},
#  {'objectid': 322994,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.0005376344086021505,
#   'css3': '#c0c0c0'},
#  {'objectid': 322994,
#   'color': '#321919',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.00021505376344086021,
#   'css3': '#000000'},
#  {'objectid': 322995,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.741256038647343,
#   'css3': '#000000'},
#  {'objectid': 322995,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.13265700483091789,
#   'css3': '#556b2f'},
#  {'objectid': 322995,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.08628019323671497,
#   'css3': '#2f4f4f'},
#  {'objectid': 322995,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.019130434782608695,
#   'css3': '#a0522d'},
#  {'objectid': 322995,
#   'color': '#191900',
#   'spectrum': '#2eb45d',
#   'hue': 'Brown',
#   'percent': 0.01884057971014493,
#   'css3': '#000000'},
#  {'objectid': 322995,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0017391304347826088,
#   'css3': '#a0522d'},
#  {'objectid': 322995,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 9.66183574879227e-05,
#   'css3': '#bdb76b'},
#  {'objectid': 322996,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7214492753623188,
#   'css3': '#000000'},
#  {'objectid': 322996,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.22183574879227053,
#   'css3': '#556b2f'},
#  {'objectid': 322996,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.049855072463768114,
#   'css3': '#a0522d'},
#  {'objectid': 322996,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.006473429951690821,
#   'css3': '#a0522d'},
#  {'objectid': 322996,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.0003864734299516908,
#   'css3': '#bdb76b'},
#  {'objectid': 322997,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.482512077294686,
#   'css3': '#000000'},
#  {'objectid': 322997,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.19004830917874396,
#   'css3': '#2f4f4f'},
#  {'objectid': 322997,
#   'color': '#4b644b',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.1468599033816425,
#   'css3': '#556b2f'},
#  {'objectid': 322997,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.09797101449275362,
#   'css3': '#808080'},
#  {'objectid': 322997,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.07497584541062802,
#   'css3': '#808080'},
#  {'objectid': 322997,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.007632850241545894,
#   'css3': '#d2b48c'},
#  {'objectid': 322998,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7482125603864734,
#   'css3': '#000000'},
#  {'objectid': 322998,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11439613526570049,
#   'css3': '#556b2f'},
#  {'objectid': 322998,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.09352657004830918,
#   'css3': '#556b2f'},
#  {'objectid': 322998,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.03729468599033817,
#   'css3': '#a0522d'},
#  {'objectid': 322998,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.006570048309178744,
#   'css3': '#cd853f'},
#  {'objectid': 322999,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7697584541062802,
#   'css3': '#000000'},
#  {'objectid': 322999,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.18067632850241547,
#   'css3': '#556b2f'},
#  {'objectid': 322999,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.049565217391304345,
#   'css3': '#696969'},
#  {'objectid': 323000,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7883091787439613,
#   'css3': '#000000'},
#  {'objectid': 323000,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.10898550724637682,
#   'css3': '#556b2f'},
#  {'objectid': 323000,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.06183574879227053,
#   'css3': '#696969'},
#  {'objectid': 323000,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.028985507246376812,
#   'css3': '#808080'},
#  {'objectid': 323000,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.007439613526570048,
#   'css3': '#808080'},
#  {'objectid': 323000,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.0024154589371980675,
#   'css3': '#d2b48c'},
#  {'objectid': 323000,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.001642512077294686,
#   'css3': '#c0c0c0'},
#  {'objectid': 323000,
#   'color': '#e1e1c8',
#   'spectrum': '#e9715f',
#   'hue': 'Green',
#   'percent': 0.0003864734299516908,
#   'css3': '#dcdcdc'},
#  {'objectid': 323001,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8428985507246377,
#   'css3': '#000000'},
#  {'objectid': 323001,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.1570048309178744,
#   'css3': '#556b2f'},
#  {'objectid': 323001,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 9.66183574879227e-05,
#   'css3': '#a0522d'},
#  {'objectid': 323002,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5122705314009662,
#   'css3': '#000000'},
#  {'objectid': 323002,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.25681159420289856,
#   'css3': '#696969'},
#  {'objectid': 323002,
#   'color': '#644b4b',
#   'spectrum': '#8362aa',
#   'hue': 'Brown',
#   'percent': 0.22966183574879226,
#   'css3': '#696969'},
#  {'objectid': 323002,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.0010628019323671498,
#   'css3': '#d2b48c'},
#  {'objectid': 323002,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.0001932367149758454,
#   'css3': '#c0c0c0'},
#  {'objectid': 323003,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.721159420289855,
#   'css3': '#000000'},
#  {'objectid': 323003,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11091787439613526,
#   'css3': '#556b2f'},
#  {'objectid': 323003,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.09410628019323672,
#   'css3': '#2f4f4f'},
#  {'objectid': 323003,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.04869565217391304,
#   'css3': '#696969'},
#  {'objectid': 323003,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.014202898550724638,
#   'css3': '#808080'},
#  {'objectid': 323003,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.008792270531400966,
#   'css3': '#808080'},
#  {'objectid': 323003,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.002028985507246377,
#   'css3': '#a9a9a9'},
#  {'objectid': 323003,
#   'color': '#197d64',
#   'spectrum': '#14b16a',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#2e8b57'},
#  {'objectid': 323212,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6766183574879227,
#   'css3': '#000000'},
#  {'objectid': 323212,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.1276328502415459,
#   'css3': '#808080'},
#  {'objectid': 323212,
#   'color': '#4b644b',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 0.10821256038647344,
#   'css3': '#556b2f'},
#  {'objectid': 323212,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.0791304347826087,
#   'css3': '#808080'},
#  {'objectid': 323212,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.006570048309178744,
#   'css3': '#2f4f4f'},
#  {'objectid': 323212,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.0018357487922705314,
#   'css3': '#a0522d'},
#  {'objectid': 323213,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7511111111111111,
#   'css3': '#000000'},
#  {'objectid': 323213,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.1051207729468599,
#   'css3': '#d2b48c'},
#  {'objectid': 323213,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.05893719806763285,
#   'css3': '#808080'},
#  {'objectid': 323213,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.042705314009661835,
#   'css3': '#808080'},
#  {'objectid': 323213,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.02608695652173913,
#   'css3': '#696969'},
#  {'objectid': 323213,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.01603864734299517,
#   'css3': '#556b2f'},
#  {'objectid': 323214,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8451207729468599,
#   'css3': '#000000'},
#  {'objectid': 323214,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.06434782608695652,
#   'css3': '#556b2f'},
#  {'objectid': 323214,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.05439613526570048,
#   'css3': '#696969'},
#  {'objectid': 323214,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.036135265700483095,
#   'css3': '#808080'},
#  {'objectid': 323215,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7944927536231884,
#   'css3': '#000000'},
#  {'objectid': 323215,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.1233816425120773,
#   'css3': '#556b2f'},
#  {'objectid': 323215,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.057681159420289854,
#   'css3': '#696969'},
#  {'objectid': 323215,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.01893719806763285,
# ...
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.04772946859903382,
#   'css3': '#808080'},
#  {'objectid': 323218,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.043671497584541065,
#   'css3': '#696969'},
#  {'objectid': 323218,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.02386473429951691,
#   'css3': '#556b2f'},
#  {'objectid': 323219,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7447342995169082,
#   'css3': '#000000'},
#  {'objectid': 323219,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.16396135265700484,
#   'css3': '#a0522d'},
#  {'objectid': 323219,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.08038647342995169,
#   'css3': '#a0522d'},
#  {'objectid': 323219,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.010628019323671498,
#   'css3': '#2f4f4f'},
#  {'objectid': 323219,
#   'color': '#194b4b',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 0.0001932367149758454,
#   'css3': '#2f4f4f'},
#  {'objectid': 323219,
#   'color': '#4b7d64',
#   'spectrum': '#3db657',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#2e8b57'},
#  {'objectid': 323220,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7907246376811594,
#   'css3': '#000000'},
#  {'objectid': 323220,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.15806763285024156,
#   'css3': '#2f4f4f'},
#  {'objectid': 323220,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.050821256038647344,
#   'css3': '#556b2f'},
#  {'objectid': 323220,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0002898550724637681,
#   'css3': '#a0522d'},
#  {'objectid': 323220,
#   'color': '#19644b',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#2f4f4f'},
#  {'objectid': 323221,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7431884057971014,
#   'css3': '#000000'},
#  {'objectid': 323221,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.07951690821256038,
#   'css3': '#696969'},
#  {'objectid': 323221,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.07024154589371981,
#   'css3': '#696969'},
#  {'objectid': 323221,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.0659903381642512,
#   'css3': '#808080'},
#  {'objectid': 323221,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.024734299516908212,
#   'css3': '#556b2f'},
#  {'objectid': 323221,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.011014492753623189,
#   'css3': '#2f4f4f'},
#  {'objectid': 323221,
#   'color': '#afaf7d',
#   'spectrum': '#9ecb3b',
#   'hue': 'Green',
#   'percent': 0.0052173913043478265,
#   'css3': '#bdb76b'},
#  {'objectid': 323221,
#   'color': '#c8c896',
#   'spectrum': '#a9cf38',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#d2b48c'},
#  {'objectid': 323222,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.5567149758454106,
#   'css3': '#000000'},
#  {'objectid': 323222,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.24492753623188407,
#   'css3': '#a0522d'},
#  {'objectid': 323222,
#   'color': '#4b4b19',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.13265700483091789,
#   'css3': '#556b2f'},
#  {'objectid': 323222,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.050241545893719805,
#   'css3': '#2f4f4f'},
#  {'objectid': 323222,
#   'color': '#967d32',
#   'spectrum': '#86c440',
#   'hue': 'Yellow',
#   'percent': 0.015458937198067632,
#   'css3': '#a0522d'},
#  {'objectid': 323223,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6017391304347826,
#   'css3': '#000000'},
#  {'objectid': 323223,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.10647342995169082,
#   'css3': '#2f4f4f'},
#  {'objectid': 323223,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.10057971014492753,
#   'css3': '#696969'},
#  {'objectid': 323223,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.09391304347826086,
#   'css3': '#556b2f'},
#  {'objectid': 323223,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.0927536231884058,
#   'css3': '#696969'},
#  {'objectid': 323223,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.004541062801932367,
#   'css3': '#bdb76b'},
#  {'objectid': 323224,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7628019323671498,
#   'css3': '#000000'},
#  {'objectid': 323224,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.12714975845410628,
#   'css3': '#556b2f'},
#  {'objectid': 323224,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.07004830917874397,
#   'css3': '#2f4f4f'},
#  {'objectid': 323224,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.03990338164251208,
#   'css3': '#696969'},
#  {'objectid': 323224,
#   'color': '#64967d',
#   'spectrum': '#47b853',
#   'hue': 'Green',
#   'percent': 9.66183574879227e-05,
#   'css3': '#708090'},
#  {'objectid': 323225,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7143961352657004,
#   'css3': '#000000'},
#  {'objectid': 323225,
#   'color': '#324b32',
#   'spectrum': '#2eb45d',
#   'hue': 'Green',
#   'percent': 0.20106280193236714,
#   'css3': '#2f4f4f'},
#  {'objectid': 323225,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.05922705314009662,
#   'css3': '#696969'},
#  {'objectid': 323225,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.020676328502415457,
#   'css3': '#696969'},
#  {'objectid': 323225,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.00463768115942029,
#   'css3': '#808080'},
#  {'objectid': 323226,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8290821256038647,
#   'css3': '#000000'},
#  {'objectid': 323226,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.13603864734299517,
#   'css3': '#2f4f4f'},
#  {'objectid': 323226,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.034879227053140095,
#   'css3': '#556b2f'},
#  {'objectid': 323227,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.9453140096618358,
#   'css3': '#000000'},
#  {'objectid': 323227,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.050917874396135265,
#   'css3': '#556b2f'},
#  {'objectid': 323227,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.00357487922705314,
#   'css3': '#000000'},
#  {'objectid': 323227,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0001932367149758454,
#   'css3': '#a0522d'},
#  {'objectid': 323228,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.9128502415458937,
#   'css3': '#000000'},
#  {'objectid': 323228,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.08608695652173913,
#   'css3': '#556b2f'},
#  {'objectid': 323228,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.000966183574879227,
#   'css3': '#a0522d'},
#  {'objectid': 323228,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 9.66183574879227e-05,
#   'css3': '#cd853f'},
#  {'objectid': 323229,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7019323671497585,
#   'css3': '#000000'},
#  {'objectid': 323229,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.14579710144927535,
#   'css3': '#556b2f'},
#  {'objectid': 323229,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.09304347826086956,
#   'css3': '#a0522d'},
#  {'objectid': 323229,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.050917874396135265,
#   'css3': '#2f4f4f'},
#  {'objectid': 323229,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.008309178743961353,
#   'css3': '#a0522d'},
#  {'objectid': 323230,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8181642512077295,
#   'css3': '#000000'},
#  {'objectid': 323230,
#   'color': '#646432',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.08367149758454107,
#   'css3': '#556b2f'},
#  {'objectid': 323230,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.07951690821256038,
#   'css3': '#556b2f'},
#  {'objectid': 323230,
#   'color': '#7d7d4b',
#   'spectrum': '#6cbd45',
#   'hue': 'Green',
#   'percent': 0.018647342995169083,
#   'css3': '#696969'},
#  {'objectid': 323231,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7019323671497585,
#   'css3': '#000000'},
#  {'objectid': 323231,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.29806763285024157,
#   'css3': '#556b2f'},
#  {'objectid': 323640,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.9470720720720721,
#   'css3': '#000000'},
#  {'objectid': 323640,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.04581081081081081,
#   'css3': '#556b2f'},
#  {'objectid': 323640,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.0046846846846846845,
#   'css3': '#696969'},
#  {'objectid': 323640,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.0024324324324324323,
#   'css3': '#000000'},
#  {'objectid': 47107,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7176190476190476,
#   'css3': '#000000'},
#  {'objectid': 47107,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.1463809523809524,
#   'css3': '#556b2f'},
#  {'objectid': 47107,
#   'color': '#643232',
#   'spectrum': '#ae5596',
#   'hue': 'Red',
#   'percent': 0.06885714285714285,
#   'css3': '#8b4513'},
#  {'objectid': 47107,
#   'color': '#7d4b32',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.0499047619047619,
#   'css3': '#8b4513'},
#  {'objectid': 47107,
#   'color': '#96644b',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.009619047619047619,
#   'css3': '#a0522d'},
#  {'objectid': 47107,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.004,
#   'css3': '#000000'},
#  {'objectid': 47107,
#   'color': '#af7d64',
#   'spectrum': '#c85783',
#   'hue': 'Brown',
#   'percent': 0.0013333333333333333,
#   'css3': '#cd5c5c'},
#  {'objectid': 47107,
#   'color': '#c87d4b',
#   'spectrum': '#ed7758',
#   'hue': 'Brown',
#   'percent': 0.001142857142857143,
#   'css3': '#cd853f'},
#  {'objectid': 47107,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.001142857142857143,
#   'css3': '#000000'},
#  {'objectid': 47583,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.44085714285714284,
#   'css3': '#000000'},
#  {'objectid': 47583,
#   'color': '#7d6464',
#   'spectrum': '#8e5ea7',
#   'hue': 'Brown',
#   'percent': 0.19095238095238096,
#   'css3': '#696969'},
#  {'objectid': 47583,
#   'color': '#644b4b',
#   'spectrum': '#8362aa',
#   'hue': 'Brown',
#   'percent': 0.17466666666666666,
#   'css3': '#696969'},
#  {'objectid': 47583,
#   'color': '#4b3232',
#   'spectrum': '#4ab851',
#   'hue': 'Red',
#   'percent': 0.11171428571428571,
#   'css3': '#2f4f4f'},
#  {'objectid': 47583,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.048666666666666664,
#   'css3': '#808080'},
#  {'objectid': 47583,
#   'color': '#af9696',
#   'spectrum': '#ae5596',
#   'hue': 'Brown',
#   'percent': 0.026476190476190476,
#   'css3': '#bc8f8f'},
#  {'objectid': 47583,
#   'color': '#c8afaf',
#   'spectrum': '#b55592',
#   'hue': 'Red',
#   'percent': 0.003904761904761905,
#   'css3': '#c0c0c0'},
#  {'objectid': 47583,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.0020952380952380953,
#   'css3': '#000000'},
#  {'objectid': 47583,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0006666666666666666,
#   'css3': '#000000'},
#  {'objectid': 47584,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.6256190476190476,
#   'css3': '#000000'},
#  {'objectid': 47584,
#   'color': '#644b4b',
#   'spectrum': '#8362aa',
#   'hue': 'Brown',
#   'percent': 0.14314285714285716,
#   'css3': '#696969'},
#  {'objectid': 47584,
#   'color': '#4b3232',
#   'spectrum': '#4ab851',
#   'hue': 'Red',
#   'percent': 0.13447619047619047,
#   'css3': '#2f4f4f'},
#  {'objectid': 47584,
#   'color': '#7d6464',
#   'spectrum': '#8e5ea7',
#   'hue': 'Brown',
#   'percent': 0.07476190476190477,
#   'css3': '#696969'},
#  {'objectid': 47584,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.020095238095238097,
#   'css3': '#808080'},
#  {'objectid': 47584,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.001142857142857143,
#   'css3': '#000000'},
#  {'objectid': 47584,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.0007619047619047619,
#   'css3': '#000000'},
#  {'objectid': 47585,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.9407619047619048,
#   'css3': '#000000'},
#  {'objectid': 47585,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.025333333333333333,
#   'css3': '#808080'},
#  {'objectid': 47585,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.023904761904761904,
#   'css3': '#808080'},
#  {'objectid': 47585,
#   'color': '#af9696',
#   'spectrum': '#ae5596',
#   'hue': 'Brown',
#   'percent': 0.008095238095238095,
#   'css3': '#bc8f8f'},
#  {'objectid': 47585,
#   'color': '#c8afaf',
#   'spectrum': '#b55592',
#   'hue': 'Red',
#   'percent': 0.0009523809523809524,
#   'css3': '#c0c0c0'},
#  {'objectid': 47585,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0006666666666666666,
#   'css3': '#000000'},
#  {'objectid': 47585,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.00028571428571428574,
#   'css3': '#000000'},
#  {'objectid': 47586,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8971428571428571,
#   'css3': '#000000'},
#  {'objectid': 47586,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.08457142857142858,
#   'css3': '#808080'},
#  {'objectid': 47586,
#   'color': '#af9696',
#   'spectrum': '#ae5596',
#   'hue': 'Brown',
#   'percent': 0.017333333333333333,
#   'css3': '#bc8f8f'},
#  {'objectid': 47586,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0009523809523809524,
#   'css3': '#000000'},
#  {'objectid': 47587,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.7350476190476191,
#   'css3': '#000000'},
#  {'objectid': 47587,
#   'color': '#7d4b32',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.12285714285714286,
#   'css3': '#8b4513'},
#  {'objectid': 47587,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.06695238095238096,
#   'css3': '#a0522d'},
#  {'objectid': 47587,
#   'color': '#643219',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.04542857142857143,
#   'css3': '#8b4513'},
#  {'objectid': 47587,
#   'color': '#af644b',
#   'spectrum': '#e0626d',
#   'hue': 'Orange',
#   'percent': 0.02457142857142857,
#   'css3': '#cd5c5c'},
#  {'objectid': 47587,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.0037142857142857142,
#   'css3': '#000000'},
#  {'objectid': 47587,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.001142857142857143,
#   'css3': '#000000'},
#  ...]

# %%
len(colors)
# Out:
# 13425

# %% [markdown]
# ##Extraction of up to 12,500 artifact records
#  (5 classifications × 2500 records each)

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.11.12)

# %%
import requests

API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"

url_1 = "https://api.harvardartmuseums.org/classification"
url_2 = "https://api.harvardartmuseums.org/object"

num_pages_to_fetch = 25
all_records = []
# classifications = ["Coins","Paintings","Sculpture","Photographs","Drawings"]
classifications = []
metadata = []
media = []
colors = []
records = []

params = {
            "apikey": API_KEY,
            "size":100,
      }
print("The classification names where the object count is >= 2500\n")
response = requests.get(url_1, params)
data = response.json()
classifications = []
for record in data["records"]:
    if record["objectcount"] >= 2500:
      if "(non-art)" in record["name"] :
        continue
      else:
        classifications.append(record["name"])
        print(f"classification name:-{record["name"]}, objectcount - {record["objectcount"]}")


print(f"-------Starting Pagination for {num_pages_to_fetch} Pages for 5 classifications-----")
for classification_name in classifications [0:5]:
  print(f"\n----- Fetching data for classification: **{classification_name}**-----")
  for page in range(1, num_pages_to_fetch + 1):
      params = {
            "apikey": API_KEY,
            "size":100,
            "page": page,
            "classification": classification_name
      }
      response = requests.get(url_2, params=params)
      response.raise_for_status()
      data = response.json()
      page_records = data.get("records", [])
      all_records.extend(page_records)
      print(f"successfully fetched len {len(page_records)} records from page {page} of {num_pages_to_fetch}.")
print(f"Total records collected: {len(all_records)}----")
print(f"Records: {len(page_records)}")
# Out:
# The classification names where the object count is >= 2500
#
# classification name:-Photographs, objectcount - 85799
# classification name:-Drawings, objectcount - 33965
# classification name:-Prints, objectcount - 72253
# classification name:-Paintings, objectcount - 6864
# classification name:-Sculpture, objectcount - 6643
# classification name:-Coins, objectcount - 20270
# classification name:-Vessels, objectcount - 6223
# classification name:-Textile Arts, objectcount - 3446
# classification name:-Archival Material, objectcount - 15737
# classification name:-Fragments, objectcount - 5218
# classification name:-Manuscripts, objectcount - 5001
# classification name:-Seals, objectcount - 5899
# classification name:-Straus Materials, objectcount - 5128
# -------Starting Pagination for 25 Pages for 5 classifications-----
#
# ----- Fetching data for classification: **Photographs**-----
# successfully fetched len 100 records from page 1 of 25.
# successfully fetched len 100 records from page 2 of 25.
# successfully fetched len 100 records from page 3 of 25.
# successfully fetched len 100 records from page 4 of 25.
# successfully fetched len 100 records from page 5 of 25.
# successfully fetched len 100 records from page 6 of 25.
# successfully fetched len 100 records from page 7 of 25.
# successfully fetched len 100 records from page 8 of 25.
# successfully fetched len 100 records from page 9 of 25.
# successfully fetched len 100 records from page 10 of 25.
# successfully fetched len 100 records from page 11 of 25.
# successfully fetched len 100 records from page 12 of 25.
# successfully fetched len 100 records from page 13 of 25.
# successfully fetched len 100 records from page 14 of 25.
# successfully fetched len 100 records from page 15 of 25.
# successfully fetched len 100 records from page 16 of 25.
# successfully fetched len 100 records from page 17 of 25.
# successfully fetched len 100 records from page 18 of 25.
# successfully fetched len 100 records from page 19 of 25.
# successfully fetched len 100 records from page 20 of 25.
# successfully fetched len 100 records from page 21 of 25.
# successfully fetched len 100 records from page 22 of 25.
# successfully fetched len 100 records from page 23 of 25.
# successfully fetched len 100 records from page 24 of 25.
# successfully fetched len 100 records from page 25 of 25.
#
# ----- Fetching data for classification: **Drawings**-----
# successfully fetched len 100 records from page 1 of 25.
# successfully fetched len 100 records from page 2 of 25.
# successfully fetched len 100 records from page 3 of 25.
# successfully fetched len 100 records from page 4 of 25.
# successfully fetched len 100 records from page 5 of 25.
# successfully fetched len 100 records from page 6 of 25.
# successfully fetched len 100 records from page 7 of 25.
# successfully fetched len 100 records from page 8 of 25.
# successfully fetched len 100 records from page 9 of 25.
# successfully fetched len 100 records from page 10 of 25.
# successfully fetched len 100 records from page 11 of 25.
# successfully fetched len 100 records from page 12 of 25.
# successfully fetched len 100 records from page 13 of 25.
# successfully fetched len 100 records from page 14 of 25.
# successfully fetched len 100 records from page 15 of 25.
# successfully fetched len 100 records from page 16 of 25.
# successfully fetched len 100 records from page 17 of 25.
# successfully fetched len 100 records from page 18 of 25.
# successfully fetched len 100 records from page 19 of 25.
# successfully fetched len 100 records from page 20 of 25.
# successfully fetched len 100 records from page 21 of 25.
# successfully fetched len 100 records from page 22 of 25.
# successfully fetched len 100 records from page 23 of 25.
# successfully fetched len 100 records from page 24 of 25.
# successfully fetched len 100 records from page 25 of 25.
#
# ----- Fetching data for classification: **Prints**-----
# successfully fetched len 100 records from page 1 of 25.
# successfully fetched len 100 records from page 2 of 25.
# successfully fetched len 100 records from page 3 of 25.
# successfully fetched len 100 records from page 4 of 25.
# successfully fetched len 100 records from page 5 of 25.
# successfully fetched len 100 records from page 6 of 25.
# successfully fetched len 100 records from page 7 of 25.
# successfully fetched len 100 records from page 8 of 25.
# successfully fetched len 100 records from page 9 of 25.
# successfully fetched len 100 records from page 10 of 25.
# successfully fetched len 100 records from page 11 of 25.
# successfully fetched len 100 records from page 12 of 25.
# successfully fetched len 100 records from page 13 of 25.
# successfully fetched len 100 records from page 14 of 25.
# successfully fetched len 100 records from page 15 of 25.
# successfully fetched len 100 records from page 16 of 25.
# successfully fetched len 100 records from page 17 of 25.
# successfully fetched len 100 records from page 18 of 25.
# successfully fetched len 100 records from page 19 of 25.
# successfully fetched len 100 records from page 20 of 25.
# successfully fetched len 100 records from page 21 of 25.
# successfully fetched len 100 records from page 22 of 25.
# successfully fetched len 100 records from page 23 of 25.
# successfully fetched len 100 records from page 24 of 25.
# successfully fetched len 100 records from page 25 of 25.
#
# ----- Fetching data for classification: **Paintings**-----
# successfully fetched len 100 records from page 1 of 25.
# successfully fetched len 100 records from page 2 of 25.
# successfully fetched len 100 records from page 3 of 25.
# successfully fetched len 100 records from page 4 of 25.
# successfully fetched len 100 records from page 5 of 25.
# successfully fetched len 100 records from page 6 of 25.
# successfully fetched len 100 records from page 7 of 25.
# successfully fetched len 100 records from page 8 of 25.
# successfully fetched len 100 records from page 9 of 25.
# successfully fetched len 100 records from page 10 of 25.
# successfully fetched len 100 records from page 11 of 25.
# successfully fetched len 100 records from page 12 of 25.
# successfully fetched len 100 records from page 13 of 25.
# successfully fetched len 100 records from page 14 of 25.
# successfully fetched len 100 records from page 15 of 25.
# successfully fetched len 100 records from page 16 of 25.
# successfully fetched len 100 records from page 17 of 25.
# successfully fetched len 100 records from page 18 of 25.
# successfully fetched len 100 records from page 19 of 25.
# successfully fetched len 100 records from page 20 of 25.
# successfully fetched len 100 records from page 21 of 25.
# successfully fetched len 100 records from page 22 of 25.
# successfully fetched len 100 records from page 23 of 25.
# successfully fetched len 100 records from page 24 of 25.
# successfully fetched len 100 records from page 25 of 25.
#
# ----- Fetching data for classification: **Sculpture**-----
# successfully fetched len 100 records from page 1 of 25.
# successfully fetched len 100 records from page 2 of 25.
# successfully fetched len 100 records from page 3 of 25.
# successfully fetched len 100 records from page 4 of 25.
# successfully fetched len 100 records from page 5 of 25.
# successfully fetched len 100 records from page 6 of 25.
# successfully fetched len 100 records from page 7 of 25.
# successfully fetched len 100 records from page 8 of 25.
# successfully fetched len 100 records from page 9 of 25.
# successfully fetched len 100 records from page 10 of 25.
# successfully fetched len 100 records from page 11 of 25.
# successfully fetched len 100 records from page 12 of 25.
# successfully fetched len 100 records from page 13 of 25.
# successfully fetched len 100 records from page 14 of 25.
# successfully fetched len 100 records from page 15 of 25.
# successfully fetched len 100 records from page 16 of 25.
# successfully fetched len 100 records from page 17 of 25.
# successfully fetched len 100 records from page 18 of 25.
# successfully fetched len 100 records from page 19 of 25.
# successfully fetched len 100 records from page 20 of 25.
# successfully fetched len 100 records from page 21 of 25.
# successfully fetched len 100 records from page 22 of 25.
# successfully fetched len 100 records from page 23 of 25.
# successfully fetched len 100 records from page 24 of 25.
# successfully fetched len 100 records from page 25 of 25.
# Total records collected: 12500----
# Records: 100

# %%
import requests

API_KEY = "568fa32d-1032-4ae1-8670-e0c5ab20a5dd"

url_1 = "https://api.harvardartmuseums.org/classification"
url_2 = "https://api.harvardartmuseums.org/object"

num_pages_to_fetch = 25
all_records = []
classifications = []
metadata = []
media = []
colors = []
records = []

params = {
            "apikey": API_KEY,
            "size":100,
      }
print("The classification names where the object count is >= 2500\n")
response = requests.get(url_1, params)
data = response.json()
classifications = []
for record in data["records"]:
    if record["objectcount"] >= 2500:
      if "(non-art)" in record["name"] :
        continue
      else:
        classifications.append(record["name"])
        print(f"classification name:-{record["name"]}, objectcount - {record["objectcount"]}")

print(f"-------Starting Pagination for {num_pages_to_fetch} Pages for classifications-----")
for classification_name in classifications [0:5]:
  print(f"\n----- Fetching data for classification: **{classification_name}**-----")

  for page in range(1, num_pages_to_fetch + 1):
      params = {
            "apikey": API_KEY,
            "size":100,
            "page": page,
            "classification": classification_name
      }
      response = requests.get(url_2, params=params)
      data = response.json()
      page_records = data.get("records", [])
      all_records.extend(page_records)

      for i in data['records']:
              metadata.append(dict(
                  id = i['id'],
                  title = i['title'],
                  culture = i['culture'],
                  period = i['period'],
                  century = i['century'],
                  medium = i['medium'],
                  dimensions = i['dimensions'],
                  description = i['description'],
                  department = i['department'],
                  classification = i['classification'],
                  accessionyear = i['accessionyear'],
                  accessionmethod = i['accessionmethod']
              ))

              media.append(dict(
                  objectid = i['objectid'],
                  imagecount = i['imagecount'],
                  mediacount = i['mediacount'],
                  colorcount = i['colorcount'],
                  rank = i['rank'],
                  datebegin = i['datebegin'],
                  dateend = i['dateend']
              ))
              color_details = i.get('colors')
              if color_details:
                  for j in color_details:
                      colors.append(dict(
                            objectid = i['objectid'],
                            color = j['color'],
                            spectrum = j['spectrum'],
                            hue = j['hue'],
                            percent = j['percent'],
                            css3 = j['css3']
                                ))

print(f"Total records collected: {len(all_records)}")
print(f"Records in a page: {len(page_records)}")

print(f"Length of metadata: {len(metadata)}")
print(f"Length of media: {len(media)}")
print(f"Length of colors: {len(colors)}")
# Out:
# The classification names where the object count is >= 2500
#
# classification name:-Photographs, objectcount - 85799
# classification name:-Drawings, objectcount - 33965
# classification name:-Prints, objectcount - 72253
# classification name:-Paintings, objectcount - 6864
# classification name:-Sculpture, objectcount - 6643
# classification name:-Coins, objectcount - 20270
# classification name:-Vessels, objectcount - 6223
# classification name:-Textile Arts, objectcount - 3446
# classification name:-Archival Material, objectcount - 15737
# classification name:-Fragments, objectcount - 5218
# classification name:-Manuscripts, objectcount - 5001
# classification name:-Seals, objectcount - 5899
# classification name:-Straus Materials, objectcount - 5128
# -------Starting Pagination for 25 Pages for classifications-----
#
# ----- Fetching data for classification: **Photographs**-----
#
# ----- Fetching data for classification: **Drawings**-----
#
# ----- Fetching data for classification: **Prints**-----
#
# ----- Fetching data for classification: **Paintings**-----
#
# ----- Fetching data for classification: **Sculpture**-----
# Total records collected: 12500----
# Records in a page: 100
# Length of metadata: 12500
# Length of media: 12500
# Length of colors: 76873

# %% [markdown]
# ##Extracting and Formating data

# %%
#api_data is a list of dictionaries
data_to_insert_metadata = []
data_to_insert_media = []
data_to_insert_colors = []

# Extract and format data as needed
for item in metadata:
   data_to_insert_metadata.append((item['id'], item['title'], item['culture'], item['period'], item['century'], item['medium'], item['dimensions'], item['description'], item['department'], item['classification'], item['accessionyear'], item['accessionmethod']))

for item in media:
   data_to_insert_media.append((item['objectid'], item['imagecount'], item['mediacount'], item['colorcount'], item['rank'], item['datebegin'], item['dateend']))

for item in colors:
   data_to_insert_colors.append((item['objectid'], item['color'], item['spectrum'], item['hue'], item['percent'], item['css3']))

# %% [markdown]
# ## SQL Insertion

# %% [markdown]
# ###Installing and creating connection to mysql

# %%
# Install mysql connector
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.5 kB)
# Downloading mysql_connector_python-9.5.0-cp312-cp312-manylinux_2_28_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 55.1 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.5.0

# %%
# Create connection to mysql
import mysql.connector
conn = mysql.connector.connect(
    host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
    user = "4Sw7vnWkyLJgtmE.root",
    password = "N1BiWHTTmOf88ojU",
    port = 4000
    )
cursor = conn.cursor()

# %% [markdown]
# ###Creating database and adding database in connection

# %%
# Create db
cursor.execute("create database Harvard_Art_Museums")

# %%
# Add database in connection
conn = mysql.connector.connect(
    host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
    user = "4Sw7vnWkyLJgtmE.root",
    password = "N1BiWHTTmOf88ojU",
    port = 4000,
    database = "Harvard_Art_Museums"
    )
cursor = conn.cursor()

# %% [markdown]
# ###Inserting data in database

# %%
#Table creation and data insertion in db

# Drop tables if they exist to allow for re-running the cell
cursor.execute("DROP TABLE IF EXISTS artifacts_metadata")
cursor.execute("DROP TABLE IF EXISTS artifacts_media")
cursor.execute("DROP TABLE IF EXISTS artifacts_colors")

# metadata table creation
cursor.execute("""create table artifacts_metadata(
    id int primary key,
    title text,
    culture text,
    period text,
    century text,
    medium text,
    dimensions text,
    description text,
    department text,
    classification text,
    accessionyear integer,
    accessionmethod text
)""")

# media table creation
cursor.execute("""create table artifacts_media(
    object_id int,
    image_count int,
    media_count int,
    color_count int,
    item_rank int,
    date_begin int,
    date_end int,
    foreign key (object_id) references artifacts_metadata(id)
)""")

# colors table creation
cursor.execute("""create table artifacts_colors(
    object_id int,
    color text,
    spectrum text,
    hue text,
    percent text,
    css3 text,
    foreign key (object_id) references artifacts_metadata(id)
)""")

print("Tables created successfully---")
print("\n Inserting data into tables---")

insert_query_metadata = "INSERT INTO artifacts_metadata values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)" # Or '?' for sqlite
insert_query_media = "INSERT INTO artifacts_media values (%s, %s, %s, %s, %s, %s, %s)"
insert_query_colors = "INSERT INTO artifacts_colors values (%s, %s, %s, %s, %s, %s)"
try:
  # insert data into metadata
        cursor.executemany(insert_query_metadata, data_to_insert_metadata)
        print(f"Inserted {len(metadata)} rows in 'metadata'---")
  # insert data into media
        cursor.executemany(insert_query_media, data_to_insert_media)
        print(f"Inserted {len(media)} rows in 'media'---")
  # insert data into colors
        cursor.executemany(insert_query_colors, data_to_insert_colors)
        print(f"Inserted {len(colors)} rows in 'colors'---")

  # Commit changes to the database
        conn.commit()
except mysql.connector.Error as err:
        print(f"Error inserting data: {err}")
        conn.rollback() # Rollback changes on error

# verify data insertion
print("\n Verifying data insertion---")
cursor.execute("use Harvard_Art_Museums")
cursor.execute("show tables")
for table in cursor.fetchall():
  print(table)

#close connection
conn.close()
print("\n Connection closed.......")
# Out:
# Tables created successfully---
#
#  Inserting data into tables---
# Inserted 12500 rows in 'metadata'---
# Inserted 12500 rows in 'media'---
# Inserted 88582 rows in 'colors'---
# 88582 records inserted.
#
#  Verifying data insertion---
# ('artifacts_colors',)
# ('artifacts_media',)
# ('artifacts_metadata',)
#
#  Connection closed.......

# %%
# conn.rollback()

# %%
# cursor.execute("DROP DATABASE Harvard_Art_Museums")
# conn.commit()
